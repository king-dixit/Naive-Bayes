# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import math 
import seaborn as sns 
from tqdm import tqdm 
from sklearn.model_selection import train_test_split

# %%
a = np.random.randint(0, 2, 3000)
a = a.reshape(1000,3)
df_naive = pd.DataFrame(a, columns=['x1','x2','y'])
df=df_naive

# %%
df
# Out:
#      x1  x2  y
# 0     0   1  1
# 1     1   1  0
# 2     1   1  1
# 3     0   0  1
# 4     1   0  0
# ..   ..  .. ..
# 995   0   1  1
# 996   0   0  0
# 997   0   0  1
# 998   1   0  1
# 999   1   0  1
#
# [1000 rows x 3 columns]

# %%
from sklearn.datasets import make_blobs
from scipy.stats import norm

# %%
class NaiveBayes:
    
    def __init__(self, df, discrete = False, laplace_smoothing = False):


        self.df = df
        self.discrete = discrete
        self.laplace_smoothing = laplace_smoothing
        self.df_train, self.df_test = train_test_split(self.df, random_state=0, test_size=0.3)
        self.X_gauss ,self.y_gauss = make_blobs(n_samples = 10000, centers = 2 , n_features = 2, random_state=1)
        self.X_train_gauss, self.X_test_gauss,self.y_train_gauss,  self.y_test_gauss = train_test_split(self.X_gauss, self.y_gauss, random_state=0, test_size=0.3)
        
        
    def fit_dist(self,data):
        mu = np.mean(data)
        sigma = np.std(data)
        dist = norm(mu, sigma)
        return dist
        
    def probability(self,X,prior, dist1,dist2 ):
        return prior * dist1.pdf(X[0]) * dist2.pdf(X[1])
    
    
    def run_model(self):

      self.X_train = self.df_train.values[:,0:2]
      self.y_train = self.df_train.values[:,2]
      self.X_test = self.df_test.values[:,0:2]
      self.y_test = self.df_test.values[:,2]
      self.X0_train = self.df_train[self.y_train==0]
      self.X1_train = self.df_train[self.y_train==1]
  

      if self.discrete and self.laplace_smoothing:
      

          lam = 1 
          
          self.prior_y0_discrete2 = (len(self.X0_train)+lam )/ (len(self.X_train) + self.df_train['y'].nunique()*lam)
          self.prior_y1_discrete2 = (len(self.X1_train)+lam )/(len(self.X_train)+ self.df_train['y'].nunique()*lam)
  
          self.X10 = self.X0_train.values[:,0]
          self.X20 = self.X0_train.values[:,1]
          self.X11 = self.X1_train.values[:,0]
          self.X21 = self.X1_train.values[:,1]

    
          #Liklihoods for (x1|y)
          self.LX10y0L = (len(self.X10[self.X10 == 0])+lam)/(len(self.X0_train)+self.df_train['x1'].nunique()*lam)
          self.LX10y1L = (len(self.X11[self.X11 == 0])+lam)/(len(self.X1_train)+self.df_train['x1'].nunique()*lam)
          self.LX11y0L = (len(self.X10[self.X10 == 1])+lam)/(len(self.X0_train)+self.df_train['x1'].nunique()*lam)
          self.LX11y1L = (len(self.X11[self.X11 == 1])+lam)/(len(self.X1_train)+self.df_train['x1'].nunique()*lam)

          #Likelihoods for (x2|y)
          self.LX20y0L = (len(self.X20[self.X20 == 0])+lam)/(len(self.X0_train)+self.df_train['x1'].nunique()*lam)
          self.LX20y1L = (len(self.X21[self.X21 == 0])+lam)/(len(self.X1_train)+self.df_train['x1'].nunique()*lam)
          self.LX21y0L = (len(self.X20[self.X20 == 1])+lam)/(len(self.X0_train)+self.df_train['x1'].nunique()*lam)
          self.LX21y1L = (len(self.X21[self.X21 == 1])+lam)/(len(self.X1_train)+self.df_train['x1'].nunique()*lam)

      elif self.discrete and not self.laplace_smoothing:
        

          lam = 1 
          
          self.prior_y0_discrete = (len(self.X0_train))/ (len(self.X_train))
          self.prior_y1_discrete = (len(self.X1_train))/(len(self.X_train))
  
          self.X10 = self.X0_train.values[:,0]
          self.X20 = self.X0_train.values[:,1]
          self.X11 = self.X1_train.values[:,0]
          self.X21 = self.X1_train.values[:,1]

    
          #Liklihoods for (x1|y)
          self.LX10y0 = (len(self.X10[self.X10 == 0])+lam)/(len(self.X0_train))
          self.LX10y1 = (len(self.X11[self.X11 == 0])+lam)/(len(self.X1_train))
          self.LX11y0 = (len(self.X10[self.X10 == 1])+lam)/(len(self.X0_train))
          self.LX11y1 = (len(self.X11[self.X11 == 1])+lam)/(len(self.X1_train))

          #Likelihoods for (x2|y)
          self.LX20y0 = (len(self.X20[self.X20 == 0])+lam)/(len(self.X0_train))
          self.LX20y1 = (len(self.X21[self.X21 == 0])+lam)/(len(self.X1_train))
          self.LX21y0 = (len(self.X20[self.X20 == 1])+lam)/(len(self.X0_train))
          self.LX21y1 = (len(self.X21[self.X21 == 1])+lam)/(len(self.X1_train))
      

      else: 

          print('Solving Using Gaussian Naive Bayes')
          
          self.X0_train = self.X_train_gauss[self.y_train_gauss == 0]
          self.X1_train = self.X_train_gauss[self.y_train_gauss == 1]
          #prior
          self.prior_y0 = len(self.X0_train) / len(self.X_train)
          self.prior_y1 = len(self.X1_train) / len(self.X_train)
        
          #pdf for class 0
        
          self.dist_X0y0 = self.fit_dist(self.X0_train[:,0])
          self.dist_X1y0 = self.fit_dist(self.X0_train[:,1])
        
         #pdf for class 1
        
          self.dist_X0y1 = self.fit_dist(self.X1_train[:,0])
          self.dist_X1y1 = self.fit_dist(self.X1_train[:,1])
  
        
        
    def predict(self):


      if self.discrete and self.laplace_smoothing:
        right = 0
        wrong = 0
        print('Solving Using Discrete Data and Laplace Smoothing')

        for sample, target in zip(self.X_test, self.y_test):
           
           
           if sample[0]==0 and sample[1] == 0 and target==0:
             
             py0 = self.prior_y0_discrete2*self.LX10y0L*self.LX20y0L
             py1 = self.prior_y1_discrete2*self.LX10y1L*self.LX20y1L
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0]==0 and sample[1] == 0 and target==1:

             py0 = self.prior_y0_discrete2*self.LX10y0L*self.LX20y0L
             py1 = self.prior_y1_discrete2*self.LX10y1L*self.LX20y1L
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 0 and sample[1] == 1 and target == 0:


             py0 = self.prior_y0_discrete2*self.LX10y0L*self.LX21y0L
             py1 = self.prior_y1_discrete2*self.LX10y1L*self.LX21y1L
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 0 and sample[1] == 1 and target == 1:

             py0 = self.prior_y0_discrete2*self.LX10y0L*self.LX21y0L
             py1 = self.prior_y1_discrete2*self.LX10y1L*self.LX21y1L
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 1 and sample[1] == 0 and target == 0:

             py0 = self.prior_y0_discrete2*self.LX11y0L*self.LX20y0L
             py1 = self.prior_y1_discrete2*self.LX11y1L*self.LX20y1L
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 1 and sample[1] == 0 and target == 1:

             py0 = self.prior_y0_discrete2*self.LX11y0L*self.LX20y0L
             py1 = self.prior_y1_discrete2*self.LX11y1L*self.LX20y1L
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):

               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             

           elif sample[0] == 1 and sample[1] == 1 and target == 0:

             py0 = self.prior_y0_discrete2*self.LX11y0L*self.LX21y0L
             py1 = self.prior_y1_discrete2*self.LX11y1L*self.LX21y1L
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 1 and sample[1] == 1 and target == 1:

             py0 = self.prior_y0_discrete2*self.LX11y0L*self.LX21y0L
             py1 = self.prior_y1_discrete2*self.LX11y1L*self.LX21y1L
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             

        print("Total Correct Classifications are :",right)
        print("Total Wrong Classifications are :", wrong)

      elif self.discrete and not self.laplace_smoothing:
        right = 0
        wrong = 0
        print('Solving Using Discrete Data without Laplace Smoothing')

        for sample, target in zip(self.X_test, self.y_test):
           
           
           if sample[0]==0 and sample[1] == 0 and target==0:
             
             py0 = self.prior_y0_discrete*self.LX10y0*self.LX20y0
             py1 = self.prior_y1_discrete*self.LX10y1*self.LX20y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0]==0 and sample[1] == 0 and target==1:

             py0 = self.prior_y0_discrete*self.LX10y0*self.LX20y0
             py1 = self.prior_y1_discrete*self.LX10y1*self.LX20y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 0 and sample[1] == 1 and target == 0:


             py0 = self.prior_y0_discrete*self.LX10y0*self.LX21y0
             py1 = self.prior_y1_discrete*self.LX10y1*self.LX21y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 0 and sample[1] == 1 and target == 1:

             py0 = self.prior_y0_discrete*self.LX10y0*self.LX21y0
             py1 = self.prior_y1_discrete*self.LX10y1*self.LX21y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 1 and sample[1] == 0 and target == 0:

             py0 = self.prior_y0_discrete*self.LX11y0*self.LX20y0
             py1 = self.prior_y1_discrete*self.LX11y1*self.LX20y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 1 and sample[1] == 0 and target == 1:

             py0 = self.prior_y0_discrete*self.LX11y0*self.LX20y0
             py1 = self.prior_y1_discrete*self.LX11y1*self.LX20y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):

               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             

           elif sample[0] == 1 and sample[1] == 1 and target == 0:

             py0 = self.prior_y0_discrete*self.LX11y0*self.LX21y0
             py1 = self.prior_y1_discrete*self.LX11y1*self.LX21y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 1 and sample[1] == 1 and target == 1:

             py0 = self.prior_y0_discrete*self.LX11y0*self.LX21y0
             py1 = self.prior_y1_discrete*self.LX11y1*self.LX21y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             

        print("Total Correct Classifications are :",right)
        print("Total Wrong Classifications are :", wrong)

     
      else:


         for sample, target in zip(self.X_test_gauss, self.y_test_gauss):
            
            py0 = self.probability(sample, self.prior_y0, self.dist_X0y0, self.dist_X1y0)
            py1 = self.probability(sample, self.prior_y1, self.dist_X0y1, self.dist_X1y1)
            
            print('p(y=0 | %s) = %.3f' % (sample, py0*100))
            print('p(y=1 | %s) = %.3f' % (sample, py1*100))
            
            print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))

# %%
nb = NaiveBayes(df,discrete = True)
nb.run_model()
nb.predict()
# Out:
# Solving Using Discrete Data without Laplace Smoothing
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 15.193
# p(y=1 | [0 1]) = 12.640
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 11.817
# p(y=1 | [1 1]) = 13.078
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 10.309
# p(y=1 | [1 0]) = 12.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 13.254
# p(y=1 | [0 0]) = 12.216
# model predicted class 0 and the truth was 0
#
# Right
#
# Total Correct Classifications are : 156
# Total Wrong Classifications are : 144

# %%
nb = NaiveBayes(df,discrete = True, laplace_smoothing=True)
nb.run_model()
nb.predict()
# Out:
# Solving Using Discrete Data and Laplace Smoothing
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.276
# p(y=1 | [1 1]) = 13.362
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 11.009
# p(y=1 | [1 0]) = 13.058
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 14.276
# p(y=1 | [0 1]) = 11.638
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.009
# p(y=1 | [0 0]) = 11.373
# model predicted class 1 and the truth was 0
#
# Wrong
#
# Total Correct Classifications are : 152
# Total Wrong Classifications are : 148

# %%
nb = NaiveBayes(df)
nb.run_model()
nb.predict()
# Out:
# Streaming output truncated to the last 5000 lines.
# p(y=0 | [-10.59517616  -3.99820675]) = 0.000
# p(y=1 | [-10.59517616  -3.99820675]) = 65.538
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-11.64586896  -3.55556409]) = 0.000
# p(y=1 | [-11.64586896  -3.55556409]) = 18.571
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-9.93851372 -2.79086708]) = 0.000
# p(y=1 | [-9.93851372 -2.79086708]) = 39.904
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-10.85674833  -3.7476321 ]) = 0.000
# p(y=1 | [-10.85674833  -3.7476321 ]) = 52.878
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.77616752  4.59309106]) = 77.427
# p(y=1 | [-1.77616752  4.59309106]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.67373263  -3.54544511]) = 0.000
# p(y=1 | [-10.67373263  -3.54544511]) = 57.178
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-10.7136271   -4.46537352]) = 0.000
# p(y=1 | [-10.7136271   -4.46537352]) = 53.358
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.8852545   4.37740679]) = 77.190
# p(y=1 | [-1.8852545   4.37740679]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.34991684  -3.78762722]) = 0.000
# p(y=1 | [-10.34991684  -3.78762722]) = 72.821
# model predicted class 1 and the truth was 1
#
# p(y=0 | [0.20044605 3.59297515]) = 10.652
# p(y=1 | [0.20044605 3.59297515]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.42771838  3.34621605]) = 32.961
# p(y=1 | [-2.42771838  3.34621605]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.66686376  2.20565588]) = 6.670
# p(y=1 | [-1.66686376  2.20565588]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.90668801  -4.86508639]) = 0.000
# p(y=1 | [-10.90668801  -4.86508639]) = 34.369
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-8.70561228 -3.90998873]) = 0.000
# p(y=1 | [-8.70561228 -3.90998873]) = 35.977
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-9
) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-7.95023301 -4.71439127]) = 0.000
# p(y=1 | [-7.95023301 -4.71439127]) = 8.022
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-10.01114472  -3.96587872]) = 0.000
# p(y=1 | [-10.01114472  -3.96587872]) = 79.160
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-8.62715671 -3.09066505]) = 0.000
# p(y=1 | [-8.62715671 -3.09066505]) = 22.303
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-9.58773378 -4.41364861]) = 0.000
# p(y=1 | [-9.58773378 -4.41364861]) = 66.448
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-7.74819022 -3.57754148]) = 0.000
# p(y=1 | [-7.74819022 -3.57754148]) = 6.504
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-11.77643024  -4.02883977]) = 0.000
# p(y=1 | [-11.77643024  -4.02883977]) = 16.109
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-11.35835085  -4.95554188]) = 0.000
# p(y=1 | [-11.35835085  -4.95554188]) = 18.894
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-2.51725175  2.25116481]) = 5.053
# p(y=1 | [-2.51725175  2.25116481]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-11.11353941  -4.57203737]) = 0.000
# p(y=1 | [-11.11353941  -4.57203737]) = 34.798
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-9.64025513 -3.62461042]) = 0.000
# p(y=1 | [-9.64025513 -3.62461042]) = 70.879
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-2.16027027  3.38312767]) = 40.739
# p(y=1 | [-2.16027027  3.38312767]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.55003745  -3.0265283 ]) = 0.000
# p(y=1 | [-10.55003745  -3.0265283 ]) = 43.506
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-9.94592169 -3.97683424]) = 0.000
# p(y=1 | [-9.94592169 -3.97683424]) = 79.173
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.49417801  5.65094893]) = 35.622
# p(y=1 | [-1.49417801  5.65094893]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.7736704   4.28631321]) = 78.269
# p(y=1 | [-1.7736704   4.28631321]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.71869146 -3.79158497]) = 0.000
# p(y=1 | [-9.71869146 -3.79158497]) = 75.630
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-3.0299898   4.56199024]) = 30.298
# p(y=1 | [-3.0299898   4.56199024]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.74990427  3.91771901]) = 69.980
# p(y=1 | [-1.74990427  3.91771901]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.96121524 -5.07627972]) = 0.000
# p(y=1 | [-9.96121524 -5.07627972]) = 42.496
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-4.16173691  5.02293821]) = 2.843
# p(y=1 | [-4.16173691  5.02293821]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.16636613 -3.75963207]) = 0.000
# p(y=1 | [-9.16636613 -3.75963207]) = 56.394
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-11.17751461  -4.64318339]) = 0.000
# p(y=1 | [-11.17751461  -4.64318339]) = 30.880
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-2.13546739  6.1393965 ]) = 15.153
# p(y=1 | [-2.13546739  6.1393965 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.30438723  4.93185008]) = 65.316
# p(y=1 | [-1.30438723  4.93185008]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.12140941  2.62817174]) = 14.071
# p(y=1 | [-2.12140941  2.62817174]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.9343832  -1.96283667]) = 0.000
# p(y=1 | [-9.9343832  -1.96283667]) = 10.735
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-10.52864967  -3.05649073]) = 0.000
# p(y=1 | [-10.52864967  -3.05649073]) = 45.255
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-8.34894684 -2.67141123]) = 0.000
# p(y=1 | [-8.34894684 -2.67141123]) = 9.456
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-4.51062945  5.22961329]) = 0.965
# p(y=1 | [-4.51062945  5.22961329]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.49434932  5.38278617]) = 48.317
# p(y=1 | [-1.49434932  5.38278617]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-4.64439604  2.00630791]) = 0.049
# p(y=1 | [-4.64439604  2.00630791]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-0.76614961  4.61507424]) = 53.349
# p(y=1 | [-0.76614961  4.61507424]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-8.91202642 -4.00005409]) = 0.000
# p(y=1 | [-8.91202642 -4.00005409]) = 45.557
# model predicted class 1 and the truth was 1
#
# p(y=0 | [
) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-11.47595214  -3.6674535 ]) = 0.000
# p(y=1 | [-11.47595214  -3.6674535 ]) = 25.147
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-2.44680824  5.01208402]) = 47.827
# p(y=1 | [-2.44680824  5.01208402]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.08323199  -4.50525555]) = 0.000
# p(y=1 | [-10.08323199  -4.50525555]) = 67.898
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-0.20813065  3.78845302]) = 23.778
# p(y=1 | [-0.20813065  3.78845302]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.00831345  4.30087115]) = 73.980
# p(y=1 | [-2.00831345  4.30087115]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.30384264  5.25607671]) = 51.980
# p(y=1 | [-1.30384264  5.25607671]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.11486781 -3.97457132]) = 0.000
# p(y=1 | [-9.11486781 -3.97457132]) = 55.174
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.16899886  3.01120684]) = 26.328
# p(y=1 | [-1.16899886  3.01120684]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.69573371  2.65537666]) = 9.562
# p(y=1 | [-2.69573371  2.65537666]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.79076869 -5.5453038 ]) = 0.000
# p(y=1 | [-9.79076869 -5.5453038 ]) = 22.182
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.10510237  4.93924877]) = 59.713
# p(y=1 | [-1.10510237  4.93924877]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-0.55320351  5.59151599]) = 21.632
# p(y=1 | [-0.55320351  5.59151599]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.02219818  -4.93885062]) = 0.000
# p(y=1 | [-10.02219818  -4.93885062]) = 49.026
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-8.24184118 -2.66042916]) = 0.000
# p(y=1 | [-8.24184118 -2.66042916]) = 7.818
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-8.94548089 -5.09779222]) = 0.000
# p(y=1 | [-8.94548089 -5.09779222]) = 24.707
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-11.4434188   -5.23095826]) = 0.000
# p(y=1 | [-11.4434188   -5.23095826]) = 12.278
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-2.10720944  4.90018811]) = 63.050
# p(y=1 | [-2.10720944  4.90018811]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.78835514  -3.94781828]) = 0.000
# p(y=1 | [-10.78835514  -3.94781828]) = 57.253
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.45540011  4.94129457]) = 67.554
# p(y=1 | [-1.45540011  4.94129457]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.37573523 -2.55565335]) = 0.000
# p(y=1 | [-9.37573523 -2.55565335]) = 24.744
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-9.21054703 -4.60366267]) = 0.000
# p(y=1 | [-9.21054703 -4.60366267]) = 48.416
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-7.48167544 -5.39277117]) = 0.000
# p(y=1 | [-7.48167544 -5.39277117]) = 1.355
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-0.61114078  5.55741117]) = 23.938
# p(y=1 | [-0.61114078  5.55741117]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-11.28946485  -2.58025709]) = 0.000
# p(y=1 | [-11.28946485  -2.58025709]) = 13.081
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-0.52035988  4.17508512]) = 41.677
# p(y=1 | [-0.52035988  4.17508512]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.58737805 -4.06239886]) = 0.000
# p(y=1 | [-9.58737805 -4.06239886]) = 73.239
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-11.36630323  -3.77412691]) = 0.000
# p(y=1 | [-11.36630323  -3.77412691]) = 30.137
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.69492783  6.51709492]) = 8.123
# p(y=1 | [-1.69492783  6.51709492]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.22944541  -4.15617189]) = 0.000
# p(y=1 | [-10.22944541  -4.15617189]) = 75.275
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.97320222  3.95477741]) = 67.850
# p(y=1 | [-1.97320222  3.95477741]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.1574065   -4.27701485]) = 0.000
# p(y=1 | [-10.1574065   -4.27701485]) = 74.120
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-8.8369372  -4.39689559]) = 0.000
# p(y=1 | [-8.8369372  -4.39689559]) = 38.234
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.73422868  4.19245808]) = 77.365
# p(y=1 | [-1.73422868  4.19245808]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.25522779  4.09736855]) = 62.860
# p(y=1 | [-2.25522779  4.09736855]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-8.69412013 -4.22067813]) = 0.000
# p(y=1 | [-8.69412013 -4.22067813]) = 34.331
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-9.98755062 -2.18551037]) = 0.000
# p(y=1 | [-9.98755062 -2.18551037]) = 16.358
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-9.24193114 -3.48086654]) = 0.000
# p(y=1 | [-9.24193114 -3.48086654]) = 54.288
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-2.8793043   6.85585852]) = 1.730
# p(y=1 | [-2.8793043   6.85585852]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-8.77904827 -3.13819942]) = 0.000
# p(y=1 | [-8.77904827 -3.13819942]) = 28.052
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-0.86149611  4.30455783]) = 58.653
# p(y=1 | [-0.86149611  4.30455783]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.55800573 -4.71728031]) = 0.000
# p(y=1 | [-9.55800573 -4.71728031]) = 54.652
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-2.05582265  2.61615453]) = 14.170
# p(y=1 | [-2.05582265  2.61615453]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.22798784  -3.84445377]) = 0.000
# p(y=1 | [-10.22798784  -3.84445377]) = 76.236
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-11.42615591  -3.44995453]) = 0.000
# p(y=1 | [-11.42615591  -3.44995453]) = 24.760
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.03657878  5.35826308]) = 41.789
# p(y=1 | [-1.03657878  5.35826308]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.38684916  5.66833575]) = 26.743
# p(y=1 | [-2.38684916  5.66833575]) = 0.000
# ...
# p(y=1 | [-2.91891839  4.87632116]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.57331465  3.80795001]) = 66.079
# p(y=1 | [-1.57331465  3.80795001]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.63579077  2.63926777]) = 16.093
# p(y=1 | [-1.63579077  2.63926777]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.67745901  3.05408748]) = 18.354
# p(y=1 | [-2.67745901  3.05408748]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-11.01189796  -4.04231511]) = 0.000
# p(y=1 | [-11.01189796  -4.04231511]) = 46.597
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.01153173  4.4147117 ]) = 65.439
# p(y=1 | [-1.01153173  4.4147117 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.85882794  5.26983519]) = 26.105
# p(y=1 | [-2.85882794  5.26983519]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-8.79954157 -6.38798027]) = 0.000
# p(y=1 | [-8.79954157 -6.38798027]) = 2.114
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-8.94857471 -4.06967532]) = 0.000
# p(y=1 | [-8.94857471 -4.06967532]) = 47.048
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-2.91758836  3.62347988]) = 25.992
# p(y=1 | [-2.91758836  3.62347988]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-0.1164947   5.78827677]) = 9.517
# p(y=1 | [-0.1164947   5.78827677]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.32233897  5.4145553 ]) = 44.976
# p(y=1 | [-1.32233897  5.4145553 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.64401275 -2.45220006]) = 0.000
# p(y=1 | [-9.64401275 -2.45220006]) = 24.040
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-10.96311929  -3.61959082]) = 0.000
# p(y=1 | [-10.96311929  -3.61959082]) = 46.293
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-11.08282806  -4.46037168]) = 0.000
# p(y=1 | [-11.08282806  -4.46037168]) = 38.300
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.42801201  3.49952613]) = 51.073
# p(y=1 | [-1.42801201  3.49952613]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.95207008  -3.56161388]) = 0.000
# p(y=1 | [-10.95207008  -3.56161388]) = 45.793
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-0.71344741  5.33290209]) = 33.547
# p(y=1 | [-0.71344741  5.33290209]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.05658089  3.05731466]) = 26.492
# p(y=1 | [-1.05658089  3.05731466]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-8.98637559 -1.15452914]) = 0.000
# p(y=1 | [-8.98637559 -1.15452914]) = 0.954
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.8863201   2.84198202]) = 22.068
# p(y=1 | [-1.8863201   2.84198202]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-4.95441831  4.49732965]) = 0.351
# p(y=1 | [-4.95441831  4.49732965]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.01339558 -4.36133831]) = 0.000
# p(y=1 | [-9.01339558 -4.36133831]) = 46.520
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-10.14548618  -4.64054647]) = 0.000
# p(y=1 | [-10.14548618  -4.64054647]) = 61.966
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-3.46420679  4.429091  ]) = 15.406
# p(y=1 | [-3.46420679  4.429091  ]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-8.8829401  -4.07913602]) = 0.000
# p(y=1 | [-8.8829401  -4.07913602]) = 43.907
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-8.12928534 -3.97950154]) = 0.000
# p(y=1 | [-8.12928534 -3.97950154]) = 14.960
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.54666875  3.51554333]) = 52.768
# p(y=1 | [-1.54666875  3.51554333]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.72743648  4.32981051]) = 44.266
# p(y=1 | [-2.72743648  4.32981051]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-7.80336984 -4.56229299]) = 0.000
# p(y=1 | [-7.80336984 -4.56229299]) = 6.578
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-4.17448453  5.22111488]) = 2.382
# p(y=1 | [-4.17448453  5.22111488]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.34893609  4.28104267]) = 75.667
# p(y=1 | [-1.34893609  4.28104267]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.81726357 -2.1711471 ]) = 0.000
# p(y=1 | [-9.81726357 -2.1711471 ]) = 15.754
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.22456158  5.31691347]) = 47.780
# p(y=1 | [-1.22456158  5.31691347]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [0.3950642  4.45989941]) = 10.283
# p(y=1 | [0.3950642  4.45989941]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-12.28875078  -4.74983455]) = 0.000
# p(y=1 | [-12.28875078  -4.74983455]) = 4.210
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-10.94415026  -2.38622984]) = 0.000
# p(y=1 | [-10.94415026  -2.38622984]) = 14.449
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.4261539   3.24461877]) = 38.979
# p(y=1 | [-1.4261539   3.24461877]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [0.06094079 6.15820782]) = 3.965
# p(y=1 | [0.06094079 6.15820782]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.08909537  -3.89876469]) = 0.000
# p(y=1 | [-10.08909537  -3.89876469]) = 78.552
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-9.62779089 -3.45014212]) = 0.000
# p(y=1 | [-9.62779089 -3.45014212]) = 65.554
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-2.46927531  4.35501716]) = 56.595
# p(y=1 | [-2.46927531  4.35501716]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-8.76595408 -4.76691985]) = 0.000
# p(y=1 | [-8.76595408 -4.76691985]) = 27.999
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-10.10551412  -5.25842152]) = 0.000
# p(y=1 | [-10.10551412  -5.25842152]) = 33.821
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-0.69585921  2.84345283]) = 14.675
# p(y=1 | [-0.69585921  2.84345283]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.90349921  4.45847041]) = 76.764
# p(y=1 | [-1.90349921  4.45847041]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.69416363  4.75549383]) = 43.205
# p(y=1 | [-2.69416363  4.75549383]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.12253567  4.62362927]) = 69.228
# p(y=1 | [-2.12253567  4.62362927]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.67932897  4.92512909]) = 69.254
# p(y=1 | [-1.67932897  4.92512909]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.27002315  3.35031773]) = 36.967
# p(y=1 | [-2.27002315  3.35031773]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-8.52105117 -5.26975812]) = 0.000
# p(y=1 | [-8.52105117 -5.26975812]) = 11.951
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.55152909  4.43590749]) = 79.197
# p(y=1 | [-1.55152909  4.43590749]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [1.19486418 4.11235759]) = 1.441
# p(y=1 | [1.19486418 4.11235759]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.9336518   -4.31846067]) = 0.000
# p(y=1 | [-10.9336518   -4.31846067]) = 47.341
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-11.0020147   -2.09545536]) = 0.000
# p(y=1 | [-11.0020147   -2.09545536]) = 8.276
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-8.73610128 -5.17309355]) = 0.000
# p(y=1 | [-8.73610128 -5.17309355]) = 17.924
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-0.93287994  4.03452993]) = 57.891
# p(y=1 | [-0.93287994  4.03452993]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.77730687 -3.64858172]) = 0.000
# p(y=1 | [-9.77730687 -3.64858172]) = 74.023
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-8.58307771 -4.20275488]) = 0.000
# p(y=1 | [-8.58307771 -4.20275488]) = 29.824
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-10.51667467  -3.19812695]) = 0.000
# p(y=1 | [-10.51667467  -3.19812695]) = 51.260
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.15157557  4.08245754]) = 67.002
# p(y=1 | [-1.15157557  4.08245754]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-10.26077749  -3.90435528]) = 0.000
# p(y=1 | [-10.26077749  -3.90435528]) = 75.970
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-9.46063394 -2.25389943]) = 0.000
# p(y=1 | [-9.46063394 -2.25389943]) = 16.197
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-0.79415228  2.10495117]) = 3.716
# p(y=1 | [-0.79415228  2.10495117]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-0.14673997  3.63049535]) = 19.442
# p(y=1 | [-0.14673997  3.63049535]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-11.29258421  -3.19672904]) = 0.000
# p(y=1 | [-11.29258421  -3.19672904]) = 25.250
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-10.09814626  -4.10198969]) = 0.000
# p(y=1 | [-10.09814626  -4.10198969]) = 77.840
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-10.16100617  -4.3766343 ]) = 0.000
# p(y=1 | [-10.16100617  -4.3766343 ]) = 71.418
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.40280498  4.02518303]) = 71.816
# p(y=1 | [-1.40280498  4.02518303]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.66528347 -3.46679822]) = 0.000
# p(y=1 | [-9.66528347 -3.46679822]) = 66.905
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-1.37910281  4.01045228]) = 70.981
# p(y=1 | [-1.37910281  4.01045228]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.18379953  4.78043324]) = 66.806
# p(y=1 | [-1.18379953  4.78043324]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.95461357 -3.70385889]) = 0.000
# p(y=1 | [-9.95461357 -3.70385889]) = 76.624
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-2.36734228  3.66210269]) = 46.160
# p(y=1 | [-2.36734228  3.66210269]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.4543593   5.52615994]) = 41.158
# p(y=1 | [-1.4543593   5.52615994]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-2.14670215  4.47611841]) = 69.916
# p(y=1 | [-2.14670215  4.47611841]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-0.51542336  2.69188212]) = 9.466
# p(y=1 | [-0.51542336  2.69188212]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-9.77921004 -2.55823735]) = 0.000
# p(y=1 | [-9.77921004 -2.55823735]) = 29.049
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-9.82675388 -3.94841667]) = 0.000
# p(y=1 | [-9.82675388 -3.94841667]) = 78.369
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-0.26973395  4.41324015]) = 31.478
# p(y=1 | [-0.26973395  4.41324015]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.15754093  3.47885251]) = 45.653
# p(y=1 | [-1.15754093  3.47885251]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-8.85442845 -5.69322958]) = 0.000
# p(y=1 | [-8.85442845 -5.69322958]) = 9.547
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-10.05223518  -3.83894309]) = 0.000
# p(y=1 | [-10.05223518  -3.83894309]) = 78.393
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-8.32590235 -3.28406147]) = 0.000
# p(y=1 | [-8.32590235 -3.28406147]) = 16.653
# model predicted class 1 and the truth was 1
#
# p(y=0 | [-2.4684071   4.96392932]) = 48.369
# p(y=1 | [-2.4684071   4.96392932]) = 0.000
# model predicted class 0 and the truth was 0
#
# p(y=0 | [-1.79844127  7.05862955]) = 2.147
# p(y=1 | [-1.79844127  7.05862955]) = 0.000
# model predicted class 0 and the truth was 0
