# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import math 
import seaborn as sns 
from tqdm import tqdm 
from sklearn.model_selection import train_test_split

# %%
a = np.random.randint(0, 2, 3000)
a = a.reshape(1000,3)
df_naive = pd.DataFrame(a, columns=['x1','x2','y'])
df=df_naive

# %%
from sklearn.datasets import make_blobs
from scipy.stats import norm

# %%
class NaiveBayes:
    
    def __init__(self, df, discrete = False, laplace_smoothing = False):


        self.df = df
        self.discrete = discrete
        self.laplace_smoothing = laplace_smoothing
        self.df_train, self.df_test = train_test_split(self.df, random_state=0, test_size=0.3)
        self.X_gauss ,self.y_gauss = make_blobs(n_samples = 10000, centers = 2 , n_features = 2, random_state=1)
        self.X_train_gauss, self.X_test_gauss,self.y_train_gauss,  self.y_test_gauss = train_test_split(self.X_gauss, self.y_gauss, random_state=0, test_size=0.3)
        
        
    def fit_dist(self,data):
        mu = np.mean(data)
        sigma = np.std(data)
        dist = norm(mu, sigma)
        return dist
        
    def probability(self,X,prior, dist1,dist2 ):
        return prior * dist1.pdf(X[0]) * dist2.pdf(X[1])
    
    
    def run_model(self):

      self.X_train = self.df_train.values[:,0:2]
      self.y_train = self.df_train.values[:,2]
      self.X_test = self.df_test.values[:,0:2]
      self.y_test = self.df_test.values[:,2]
      self.X0_train = self.df_train[self.y_train==0]
      self.X1_train = self.df_train[self.y_train==1]
  

      if self.discrete and not self.laplace_smoothing:

          print('Solving Using Discrete Data Without Laplace smoothing by fitting into PDF')
  
          self.prior_y0_discrete = len(self.X0_train) / len(self.X_train)
          self.prior_y1_discrete = len(self.X1_train) / len(self.X_train)

          self.dist_X0y0 = self.fit_dist(self.X0_train.values[:,0])
          self.dist_X1y0 = self.fit_dist(self.X0_train.values[:,1])

          self.dist_X0y1 = self.fit_dist(self.X1_train.values[:,0])
          self.dist_X1y1 = self.fit_dist(self.X1_train.values[:,1])

          self.prior_y0_discrete = len(self.X0_train) / len(self.X_train)
          self.prior_y1_discrete = len(self.X1_train) / len(self.X_train)


      elif self.discrete and self.laplace_smoothing:
        
          print("Solving using manual method with laplace smoothing")

          lam = 1 

          self.prior_y0_discrete = (len(self.X0_train)+lam )/ (len(self.X_train) + self.df_train['y'].nunique()*lam)
          self.prior_y1_discrete = (len(self.X1_train)+lam )/(len(self.X_train)+ self.df_train['y'].nunique()*lam)
  
          self.X10 = self.X0_train.values[:,0]
          self.X20 = self.X0_train.values[:,1]
          self.X11 = self.X1_train.values[:,0]
          self.X21 = self.X1_train.values[:,1]

          #Liklihoods for (x1|y)
          self.LX10y0 = (len(self.X10[self.X10 == 0])+lam)/(len(self.X0_train)+self.df_train['x1'].nunique()*lam)
          self.LX10y1 = (len(self.X11[self.X11 == 0])+lam)/(len(self.X1_train)+self.df_train['x1'].nunique()*lam)
          self.LX11y0 = (len(self.X10[self.X10 == 1])+lam)/(len(self.X0_train)+self.df_train['x1'].nunique()*lam)
          self.LX11y1 = (len(self.X11[self.X11 == 1])+lam)/(len(self.X1_train)+self.df_train['x1'].nunique()*lam)

          #Likelihoods for (x2|y)
          self.LX20y0 = (len(self.X20[self.X20 == 0])+lam)/(len(self.X0_train)+self.df_train['x2'].nunique()*lam)
          self.LX20y1 = (len(self.X21[self.X21 == 0])+lam)/(len(self.X1_train)+self.df_train['x2'].nunique()*lam)
          self.LX21y0 = (len(self.X20[self.X20 == 1])+lam)/(len(self.X0_train)+self.df_train['x2'].nunique()*lam)
          self.LX21y1 = (len(self.X21[self.X21 == 1])+lam)/(len(self.X1_train)+self.df_train['x2'].nunique()*lam)
      

      else: 

          print('Solving Using Gaussian Naive Bayes')
          
          self.X0_train = self.X_train_gauss[self.y_train_gauss == 0]
          self.X1_train = self.X_train_gauss[self.y_train_gauss == 1]
          #prior
          self.prior_y0 = len(self.X0_train) / len(self.X_train)
          self.prior_y1 = len(self.X1_train) / len(self.X_train)
        
          #pdf for class 0
          self.dist_X0y0 = self.fit_dist(self.X0_train[:,0])
          self.dist_X1y0 = self.fit_dist(self.X0_train[:,1])
        
         #pdf for class 1
          self.dist_X0y1 = self.fit_dist(self.X1_train[:,0])
          self.dist_X1y1 = self.fit_dist(self.X1_train[:,1])
  
        
        
    def predict(self):
     

      if self.discrete and not self.laplace_smoothing:

        right2 = 0
        wrong2 = 0

        for sample, target in zip(self.X_test, self.y_test):
            
            py0 = self.probability(sample, self.prior_y0_discrete, self.dist_X0y0, self.dist_X1y0)
            py1 = self.probability(sample, self.prior_y1_discrete, self.dist_X0y1, self.dist_X1y1)
            
            print('p(y=0 | %s) = %.3f' % (sample, py0*100))
            print('p(y=1 | %s) = %.3f' % (sample, py1*100))

            print('model predicted class {} and the truth was {} \n\n' .format(np.argmax([py0*100,py1*100]), target))
            if (np.argmax([py0*100,py1*100]) == target):
              print('Right\n')
              right2+=1
            else:
              print('Wrong\n')
              wrong2+=1

            print("Total Correct Classifications are :",right2)
            print("Total Wrong Classifications are :", wrong2)


      elif self.discrete and self.laplace_smoothing:
        right = 0
        wrong = 0


        for sample, target in zip(self.X_test, self.y_test):
           
           
           if sample[0]==0 and sample[1] == 0 and target==0:
             
             py0 = self.prior_y0_discrete*self.LX10y0*self.LX20y0
             py1 = self.prior_y1_discrete*self.LX10y1*self.LX20y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0]==0 and sample[1] == 0 and target==1:

             py0 = self.prior_y0_discrete*self.LX10y0*self.LX20y0
             py1 = self.prior_y1_discrete*self.LX10y1*self.LX20y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 0 and sample[1] == 1 and target == 0:


             py0 = self.prior_y0_discrete*self.LX10y0*self.LX21y0
             py1 = self.prior_y1_discrete*self.LX10y1*self.LX21y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))

             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 0 and sample[1] == 1 and target == 1:

             py0 = self.prior_y0_discrete*self.LX10y0*self.LX21y0
             py1 = self.prior_y1_discrete*self.LX10y1*self.LX21y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 1 and sample[1] == 0 and target == 0:

             py0 = self.prior_y0_discrete*self.LX11y0*self.LX20y0
             py1 = self.prior_y1_discrete*self.LX11y1*self.LX20y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))

             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 1 and sample[1] == 0 and target == 1:

             py0 = self.prior_y0_discrete*self.LX11y0*self.LX20y0
             py1 = self.prior_y1_discrete*self.LX11y1*self.LX20y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):

               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             

           elif sample[0] == 1 and sample[1] == 1 and target == 0:

             py0 = self.prior_y0_discrete*self.LX11y0*self.LX21y0
             py1 = self.prior_y1_discrete*self.LX11y1*self.LX21y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             
           elif sample[0] == 1 and sample[1] == 1 and target == 1:

             py0 = self.prior_y0_discrete*self.LX11y0*self.LX21y0
             py1 = self.prior_y1_discrete*self.LX11y1*self.LX21y1
             print('p(y=0 | %s) = %.3f' % (sample, py0*100))
             print('p(y=1 | %s) = %.3f' % (sample, py1*100))
             print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
             if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right+=1
             else:
               print('Wrong\n')
               wrong+=1
             

        print("Total Correct Classifications are :",right)
        print("Total Wrong Classifications are :", wrong)

     
      else:

        right3 = 0
        wrong3 = 0
        for sample, target in zip(self.X_test_gauss, self.y_test_gauss):
            
            py0 = self.probability(sample, self.prior_y0, self.dist_X0y0, self.dist_X1y0)
            py1 = self.probability(sample, self.prior_y1, self.dist_X0y1, self.dist_X1y1)
            
            print('p(y=0 | %s) = %.3f' % (sample, py0*100))
            print('p(y=1 | %s) = %.3f' % (sample, py1*100))
            
            print('model predicted class {} and the truth was {} \n' .format(np.argmax([py0*100,py1*100]), target))
            if (np.argmax([py0*100,py1*100]) == target):
               print('Right\n')
               right3+=1
            else:
               print('Wrong\n')
               wrong3+=1
             

        print("Total Correct Classifications are :",right3)
        print("Total Wrong Classifications are :", wrong3)

# %%
nb = NaiveBayes(df,discrete = True)
nb.run_model()
nb.predict()
# Out:
# Solving Using Discrete Data Without Laplace smoothing by fitting into PDF
#
# Solving using discrete data with pdf function
#
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 1
# Total Wrong Classifications are : 0
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 2
# Total Wrong Classifications are : 0
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 3
# Total Wrong Classifications are : 0
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 3
# Total Wrong Classifications are : 1
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 4
# Total Wrong Classifications are : 1
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 5
# Total Wrong Classifications are : 1
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 6
# Total Wrong Classifications are : 1
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 6
# Total Wrong Classifications are : 2
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 7
# Total Wrong Classifications are : 2
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 8
# Total Wrong Classifications are : 2
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 8
# Total Wrong Classifications are : 3
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 9
# Total Wrong Classifications are : 3
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 10
# Total Wrong Classifications are : 3
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 10
# Total Wrong Classifications are : 4
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 11
# Total Wrong Classifications are : 4
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 12
# Total Wrong Classifications are : 4
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 12
# Total Wrong Classifications are : 5
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 12
# Total Wrong Classifications are : 6
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 12
# Total Wrong Classifications are : 7
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 12
# Total Wrong Classifications are : 8
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 13
# Total Wrong Classifications are : 8
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 14
# Total Wrong Classifications are : 8
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 15
# Total Wrong Classifications are : 8
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 16
# Total Wrong Classifications are : 8
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 17
# Total Wrong Classifications are : 8
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 18
# Total Wrong Classifications are : 8
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 19
# Total Wrong Classifications are : 8
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 20
# Total Wrong Classifications are : 8
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 21
# Total Wrong Classifications are : 8
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 21
# Total Wrong Classifications are : 9
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 22
# Total Wrong Classifications are : 9
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 23
# Total Wrong Classifications are : 9
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 24
# Total Wrong Classifications are : 9
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 24
# Total Wrong Classifications are : 10
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 24
# Total Wrong Classifications are : 11
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 24
# Total Wrong Classifications are : 12
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 24
# Total Wrong Classifications are : 13
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 25
# Total Wrong Classifications are : 13
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 26
# Total Wrong Classifications are : 13
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 27
# Total Wrong Classifications are : 13
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 28
# Total Wrong Classifications are : 13
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 29
# Total Wrong Classifications are : 13
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 30
# Total Wrong Classifications are : 13
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 31
# Total Wrong Classifications are : 13
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 32
# Total Wrong Classifications are : 13
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 32
# Total Wrong Classifications are : 14
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 32
# Total Wrong Classifications are : 15
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 33
# Total Wrong Classifications are : 15
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 34
# Total Wrong Classifications are : 15
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 35
# Total Wrong Classifications are : 15
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 35
# Total Wrong Classifications are : 16
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 36
# Total Wrong Classifications are : 16
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 36
# Total Wrong Classifications are : 17
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 36
# Total Wrong Classifications are : 18
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 37
# Total Wrong Classifications are : 18
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 38
# Total Wrong Classifications are : 18
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 39
# Total Wrong Classifications are : 18
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 40
# Total Wrong Classifications are : 18
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 41
# Total Wrong Classifications are : 18
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 42
# Total Wrong Classifications are : 18
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 42
# Total Wrong Classifications are : 19
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 42
# Total Wrong Classifications are : 20
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 43
# Total Wrong Classifications are : 20
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 43
# Total Wrong Classifications are : 21
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 43
# Total Wrong Classifications are : 22
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 43
# Total Wrong Classifications are : 23
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 44
# Total Wrong Classifications are : 23
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 44
# Total Wrong Classifications are : 24
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 45
# Total Wrong Classifications are : 24
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 46
# Total Wrong Classifications are : 24
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 47
# Total Wrong Classifications are : 24
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 48
# Total Wrong Classifications are : 24
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 48
# Total Wrong Classifications are : 25
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 49
# Total Wrong Classifications are : 25
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 49
# Total Wrong Classifications are : 26
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 49
# Total Wrong Classifications are : 27
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 50
# Total Wrong Classifications are : 27
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 51
# Total Wrong Classifications are : 27
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 52
# Total Wrong Classifications are : 27
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 53
# Total Wrong Classifications are : 27
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 54
# Total Wrong Classifications are : 27
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 54
# Total Wrong Classifications are : 28
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 55
# Total Wrong Classifications are : 28
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 56
# Total Wrong Classifications are : 28
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 57
# Total Wrong Classifications are : 28
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 57
# Total Wrong Classifications are : 29
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 58
# Total Wrong Classifications are : 29
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 58
# Total Wrong Classifications are : 30
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 58
# Total Wrong Classifications are : 31
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 59
# Total Wrong Classifications are : 31
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 59
# Total Wrong Classifications are : 32
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 60
# Total Wrong Classifications are : 32
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 61
# Total Wrong Classifications are : 32
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 62
# Total Wrong Classifications are : 32
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 63
# Total Wrong Classifications are : 32
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 63
# Total Wrong Classifications are : 33
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 63
# Total Wrong Classifications are : 34
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 63
# Total Wrong Classifications are : 35
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 64
# Total Wrong Classifications are : 35
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 64
# Total Wrong Classifications are : 36
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 65
# Total Wrong Classifications are : 36
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 65
# Total Wrong Classifications are : 37
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 65
# Total Wrong Classifications are : 38
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 65
# Total Wrong Classifications are : 39
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 66
# Total Wrong Classifications are : 39
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 67
# Total Wrong Classifications are : 39
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 67
# Total Wrong Classifications are : 40
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 68
# Total Wrong Classifications are : 40
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 69
# Total Wrong Classifications are : 40
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 70
# Total Wrong Classifications are : 40
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 71
# Total Wrong Classifications are : 40
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 72
# Total Wrong Classifications are : 40
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 72
# Total Wrong Classifications are : 41
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 73
# Total Wrong Classifications are : 41
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 73
# Total Wrong Classifications are : 42
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 74
# Total Wrong Classifications are : 42
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 75
# Total Wrong Classifications are : 42
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 75
# Total Wrong Classifications are : 43
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 76
# Total Wrong Classifications are : 43
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 76
# Total Wrong Classifications are : 44
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 76
# Total Wrong Classifications are : 45
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 76
# Total Wrong Classifications are : 46
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 77
# Total Wrong Classifications are : 46
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 77
# Total Wrong Classifications are : 47
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 78
# Total Wrong Classifications are : 47
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 78
# Total Wrong Classifications are : 48
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 78
# Total Wrong Classifications are : 49
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 79
# Total Wrong Classifications are : 49
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 79
# Total Wrong Classifications are : 50
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 79
# Total Wrong Classifications are : 51
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 79
# Total Wrong Classifications are : 52
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 80
# Total Wrong Classifications are : 52
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 81
# Total Wrong Classifications are : 52
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 81
# Total Wrong Classifications are : 53
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 82
# Total Wrong Classifications are : 53
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 82
# Total Wrong Classifications are : 54
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 83
# Total Wrong Classifications are : 54
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 84
# Total Wrong Classifications are : 54
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 84
# Total Wrong Classifications are : 55
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 84
# Total Wrong Classifications are : 56
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 85
# Total Wrong Classifications are : 56
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 86
# Total Wrong Classifications are : 56
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 86
# Total Wrong Classifications are : 57
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 87
# Total Wrong Classifications are : 57
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 87
# Total Wrong Classifications are : 58
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 88
# Total Wrong Classifications are : 58
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 89
# Total Wrong Classifications are : 58
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 90
# Total Wrong Classifications are : 58
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 91
# Total Wrong Classifications are : 58
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 92
# Total Wrong Classifications are : 58
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 92
# Total Wrong Classifications are : 59
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 93
# Total Wrong Classifications are : 59
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 93
# Total Wrong Classifications are : 60
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 94
# Total Wrong Classifications are : 60
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 94
# Total Wrong Classifications are : 61
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 95
# Total Wrong Classifications are : 61
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 95
# Total Wrong Classifications are : 62
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 95
# Total Wrong Classifications are : 63
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 95
# Total Wrong Classifications are : 64
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 95
# Total Wrong Classifications are : 65
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 96
# Total Wrong Classifications are : 65
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 96
# Total Wrong Classifications are : 66
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 96
# Total Wrong Classifications are : 67
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 96
# Total Wrong Classifications are : 68
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 97
# Total Wrong Classifications are : 68
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 98
# Total Wrong Classifications are : 68
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 98
# Total Wrong Classifications are : 69
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 98
# Total Wrong Classifications are : 70
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 98
# Total Wrong Classifications are : 71
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 99
# Total Wrong Classifications are : 71
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 100
# Total Wrong Classifications are : 71
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 101
# Total Wrong Classifications are : 71
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 102
# Total Wrong Classifications are : 71
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 102
# Total Wrong Classifications are : 72
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 103
# Total Wrong Classifications are : 72
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 104
# Total Wrong Classifications are : 72
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 104
# Total Wrong Classifications are : 73
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 105
# Total Wrong Classifications are : 73
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 105
# Total Wrong Classifications are : 74
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 105
# Total Wrong Classifications are : 75
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 105
# Total Wrong Classifications are : 76
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 106
# Total Wrong Classifications are : 76
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 107
# Total Wrong Classifications are : 76
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 107
# Total Wrong Classifications are : 77
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 107
# Total Wrong Classifications are : 78
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 107
# Total Wrong Classifications are : 79
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 108
# Total Wrong Classifications are : 79
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 108
# Total Wrong Classifications are : 80
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 109
# Total Wrong Classifications are : 80
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 109
# Total Wrong Classifications are : 81
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 109
# Total Wrong Classifications are : 82
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 110
# Total Wrong Classifications are : 82
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 111
# Total Wrong Classifications are : 82
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 112
# Total Wrong Classifications are : 82
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 113
# Total Wrong Classifications are : 82
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 113
# Total Wrong Classifications are : 83
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 113
# Total Wrong Classifications are : 84
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 113
# Total Wrong Classifications are : 85
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 113
# Total Wrong Classifications are : 86
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 113
# Total Wrong Classifications are : 87
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 114
# Total Wrong Classifications are : 87
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 114
# Total Wrong Classifications are : 88
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 114
# Total Wrong Classifications are : 89
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 114
# Total Wrong Classifications are : 90
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 115
# Total Wrong Classifications are : 90
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 115
# Total Wrong Classifications are : 91
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 116
# Total Wrong Classifications are : 91
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 117
# Total Wrong Classifications are : 91
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 118
# Total Wrong Classifications are : 91
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 118
# Total Wrong Classifications are : 92
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 119
# Total Wrong Classifications are : 92
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 119
# Total Wrong Classifications are : 93
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 120
# Total Wrong Classifications are : 93
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 120
# Total Wrong Classifications are : 94
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 120
# Total Wrong Classifications are : 95
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 121
# Total Wrong Classifications are : 95
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 121
# Total Wrong Classifications are : 96
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 122
# Total Wrong Classifications are : 96
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 123
# Total Wrong Classifications are : 96
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 123
# Total Wrong Classifications are : 97
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 124
# Total Wrong Classifications are : 97
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 124
# Total Wrong Classifications are : 98
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 124
# Total Wrong Classifications are : 99
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 125
# Total Wrong Classifications are : 99
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 126
# Total Wrong Classifications are : 99
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 126
# Total Wrong Classifications are : 100
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 127
# Total Wrong Classifications are : 100
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 127
# Total Wrong Classifications are : 101
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 128
# Total Wrong Classifications are : 101
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 128
# Total Wrong Classifications are : 102
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 129
# Total Wrong Classifications are : 102
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 129
# Total Wrong Classifications are : 103
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 130
# Total Wrong Classifications are : 103
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 131
# Total Wrong Classifications are : 103
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 132
# Total Wrong Classifications are : 103
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 132
# Total Wrong Classifications are : 104
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 133
# Total Wrong Classifications are : 104
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 134
# Total Wrong Classifications are : 104
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 135
# Total Wrong Classifications are : 104
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 135
# Total Wrong Classifications are : 105
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 136
# Total Wrong Classifications are : 105
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 136
# Total Wrong Classifications are : 106
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 136
# Total Wrong Classifications are : 107
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 137
# Total Wrong Classifications are : 107
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 138
# Total Wrong Classifications are : 107
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 139
# Total Wrong Classifications are : 107
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 140
# Total Wrong Classifications are : 107
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 140
# Total Wrong Classifications are : 108
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 141
# Total Wrong Classifications are : 108
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 142
# Total Wrong Classifications are : 108
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 143
# Total Wrong Classifications are : 108
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 143
# Total Wrong Classifications are : 109
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 143
# Total Wrong Classifications are : 110
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 144
# Total Wrong Classifications are : 110
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 144
# Total Wrong Classifications are : 111
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 144
# Total Wrong Classifications are : 112
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 145
# Total Wrong Classifications are : 112
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 146
# Total Wrong Classifications are : 112
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 147
# Total Wrong Classifications are : 112
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 148
# Total Wrong Classifications are : 112
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 148
# Total Wrong Classifications are : 113
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 149
# Total Wrong Classifications are : 113
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 150
# Total Wrong Classifications are : 113
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 151
# Total Wrong Classifications are : 113
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 151
# Total Wrong Classifications are : 114
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 151
# Total Wrong Classifications are : 115
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 152
# Total Wrong Classifications are : 115
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 152
# Total Wrong Classifications are : 116
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 152
# Total Wrong Classifications are : 117
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 153
# Total Wrong Classifications are : 117
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 154
# Total Wrong Classifications are : 117
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 155
# Total Wrong Classifications are : 117
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 155
# Total Wrong Classifications are : 118
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 156
# Total Wrong Classifications are : 118
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 156
# Total Wrong Classifications are : 119
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 157
# Total Wrong Classifications are : 119
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 158
# Total Wrong Classifications are : 119
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 158
# Total Wrong Classifications are : 120
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 158
# Total Wrong Classifications are : 121
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 158
# Total Wrong Classifications are : 122
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 159
# Total Wrong Classifications are : 122
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 159
# Total Wrong Classifications are : 123
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 160
# Total Wrong Classifications are : 123
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 160
# Total Wrong Classifications are : 124
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 161
# Total Wrong Classifications are : 124
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 161
# Total Wrong Classifications are : 125
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 161
# Total Wrong Classifications are : 126
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 162
# Total Wrong Classifications are : 126
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 162
# Total Wrong Classifications are : 127
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 163
# Total Wrong Classifications are : 127
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 164
# Total Wrong Classifications are : 127
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 164
# Total Wrong Classifications are : 128
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 165
# Total Wrong Classifications are : 128
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 165
# Total Wrong Classifications are : 129
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 166
# Total Wrong Classifications are : 129
# p(y=0 | [0 1]) = 12.816
# p(y=1 | [0 1]) = 9.747
# model predicted class 0 and the truth was 0
#
#
# Right
#
# Total Correct Classifications are : 167
# Total Wrong Classifications are : 129
# p(y=0 | [0 0]) = 10.604
# p(y=1 | [0 0]) = 11.799
# model predicted class 1 and the truth was 1
#
#
# Right
#
# Total Correct Classifications are : 168
# Total Wrong Classifications are : 129
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 168
# Total Wrong Classifications are : 130
# p(y=0 | [1 1]) = 13.696
# p(y=1 | [1 1]) = 10.717
# model predicted class 0 and the truth was 1
#
#
# Wrong
#
# Total Correct Classifications are : 168
# Total Wrong Classifications are : 131
# p(y=0 | [1 0]) = 11.331
# p(y=1 | [1 0]) = 12.973
# model predicted class 1 and the truth was 0
#
#
# Wrong
#
# Total Correct Classifications are : 168
# Total Wrong Classifications are : 132

# %%
nb = NaiveBayes(df,discrete = True, laplace_smoothing=True)
nb.run_model()
nb.predict()
# Out:
# Solving using manual method with laplace smoothing
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 1]) = 13.669
# p(y=1 | [0 1]) = 10.422
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0 0]) = 11.333
# p(y=1 | [0 0]) = 12.587
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# p(y=0 | [1 1]) = 14.601
# p(y=1 | [1 1]) = 11.451
# model predicted class 0 and the truth was 1
#
# Wrong
#
# p(y=0 | [1 0]) = 12.106
# p(y=1 | [1 0]) = 13.830
# model predicted class 1 and the truth was 0
#
# Wrong
#
# Total Correct Classifications are : 168
# Total Wrong Classifications are : 132

# %%
nb = NaiveBayes(df)
nb.run_model()
nb.predict()
# Out:
# Streaming output truncated to the last 5000 lines.
# p(y=0 | [-0.31935223  5.05798477]) = 27.055
# p(y=1 | [-0.31935223  5.05798477]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.35561304 -4.45060481]) = 0.000
# p(y=1 | [-9.35561304 -4.45060481]) = 58.251
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.21901341  -5.47776599]) = 0.000
# p(y=1 | [-10.21901341  -5.47776599]) = 24.318
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.01396112  -4.26191722]) = 0.000
# p(y=1 | [-11.01396112  -4.26191722]) = 44.585
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.7206192   4.98118509]) = 44.245
# p(y=1 | [-0.7206192   4.98118509]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.79593242  3.03720946]) = 30.118
# p(y=1 | [-1.79593242  3.03720946]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.69220703 -3.92051815]) = 0.000
# p(y=1 | [-9.69220703 -3.92051815]) = 76.127
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.15596884  1.18735776]) = 0.347
# p(y=1 | [-2.15596884  1.18735776]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.5800585   -4.59677322]) = 0.000
# p(y=1 | [-10.5800585   -4.59677322]) = 54.056
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.7320981  6.5437837]) = 4.263
# p(y=1 | [-2.7320981  6.5437837]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.67765549  -3.37086376]) = 0.000
# p(y=1 | [-10.67765549  -3.37086376]) = 52.229
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.39246763  -2.90226854]) = 0.000
# p(y=1 | [-10.39246763  -2.90226854]) = 41.499
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.67870512 -5.05119769]) = 0.000
# p(y=1 | [-9.67870512 -5.05119769]) = 41.864
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.32408941 -4.28055015]) = 0.000
# p(y=1 | [-9.32408941 -4.28055015]) = 61.195
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.16415143 -4.07949722]) = 0.000
# p(y=1 | [-8.16415143 -4.07949722]) = 15.814
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.12863869  5.83381926]) = 24.636
# p(y=1 | [-1.12863869  5.83381926]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.55910446 -4.70800614]) = 0.000
# p(y=1 | [-9.55910446 -4.70800614]) = 55.060
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.9825524  -3.99703189]) = 0.000
# p(y=1 | [-9.9825524  -3.99703189]) = 79.159
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.80229745 -4.48427419]) = 0.000
# p(y=1 | [-9.80229745 -4.48427419]) = 68.073
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.85968228 -5.94356659]) = 0.000
# p(y=1 | [-9.85968228 -5.94356659]) = 11.005
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.93219158 -4.06809246]) = 0.000
# p(y=1 | [-8.93219158 -4.06809246]) = 46.282
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.27663338  4.25755315]) = 64.407
# p(y=1 | [-2.27663338  4.25755315]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.56902345 -3.82688269]) = 0.000
# p(y=1 | [-8.56902345 -3.82688269]) = 29.855
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.91900345  3.45278927]) = 38.638
# p(y=1 | [-0.91900345  3.45278927]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-11.67815665  -4.47913107]) = 0.000
# p(y=1 | [-11.67815665  -4.47913107]) = 16.710
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-3.50481084  5.2650938 ]) = 9.813
# p(y=1 | [-3.50481084  5.2650938 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.14404126 -5.32518845]) = 0.000
# p(y=1 | [-9.14404126 -5.32518845]) = 22.268
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.90822267  4.54688531]) = 60.441
# p(y=1 | [-0.90822267  4.54688531]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.80456981 -5.3340982 ]) = 0.000
# p(y=1 | [-9.80456981 -5.3340982 ]) = 30.396
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.42726451  2.60265898]) = 14.718
# p(y=1 | [-1.42726451  2.60265898]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.94431083 -4.8826909 ]) = 0.000
# p(y=1 | [-9.94431083 -4.8826909 ]) = 51.750
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.93810102  2.99539141]) = 12.511
# p(y=1 | [-2.93810102  2.99539141]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.7614664  -3.4826819]) = 0.000
# p(y=1 | [-10.7614664  -3.4826819]) = 52.155
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.00051011  2.77905153]) = 16.763
# p(y=1 | [-1.00051011  2.77905153]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.24597221 -5.95131247]) = 0.000
# p(y=1 | [-9.24597221 -5.95131247]) = 8.412
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.17417618  4.71955112]) = 65.725
# p(y=1 | [-2.17417618  4.71955112]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.37869621 -2.67883144]) = 0.000
# p(y=1 | [-9.37869621 -2.67883144]) = 29.253
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-3.09187317  3.79889283]) = 23.288
# p(y=1 | [-3.09187317  3.79889283]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.52341201  3.89891759]) = 69.255
# p(y=1 | [-1.52341201  3.89891759]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.6190564   4.46548329]) = 79.382
# p(y=1 | [-1.6190564   4.46548329]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.34598008  -4.45376345]) = 0.000
# p(y=1 | [-10.34598008  -4.45376345]) = 65.554
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.58103473 -3.16585816]) = 0.000
# p(y=1 | [-9.58103473 -3.16585816]) = 53.526
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.39174739  -5.16578348]) = 0.000
# p(y=1 | [-11.39174739  -5.16578348]) = 14.319
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.60192784  4.35239624]) = 50.330
# p(y=1 | [-2.60192784  4.35239624]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.7596284  -4.14973229]) = 0.000
# p(y=1 | [-8.7596284  -4.14973229]) = 37.788
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.08998054  -4.12782325]) = 0.000
# p(y=1 | [-10.08998054  -4.12782325]) = 77.605
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.7282499  -3.63489217]) = 0.000
# p(y=1 | [-9.7282499  -3.63489217]) = 72.920
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.78609211 -2.95943917]) = 0.000
# p(y=1 | [-9.78609211 -2.95943917]) = 47.132
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.17879601  -3.00105267]) = 0.000
# p(y=1 | [-10.17879601  -3.00105267]) = 48.941
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.41787414  4.19984209]) = 37.227
# p(y=1 | [-0.41787414  4.19984209]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.77999434 -5.92290648]) = 0.000
# p(y=1 | [-9.77999434 -5.92290648]) = 11.326
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.65778549  4.99467627]) = 66.618
# p(y=1 | [-1.65778549  4.99467627]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.62844197  5.62948631]) = 22.316
# p(y=1 | [-0.62844197  5.62948631]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.15891471  4.20782588]) = 68.269
# p(y=1 | [-2.15891471  4.20782588]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.11251342  -5.72473952]) = 0.000
# p(y=1 | [-10.11251342  -5.72473952]) = 16.539
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.32346256 -3.2350154 ]) = 0.000
# p(y=1 | [-9.32346256 -3.2350154 ]) = 49.459
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-7.60003896 -3.42282468]) = 0.000
# p(y=1 | [-7.60003896 -3.42282468]) = 4.338
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.87167489  4.00773657]) = 34.706
# p(y=1 | [-2.87167489  4.00773657]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.20684628  5.96005509]) = 21.075
# p(y=1 | [-1.20684628  5.96005509]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.38877422  5.17315858]) = 57.060
# p(y=1 | [-1.38877422  5.17315858]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.03579191  4.08560307]) = 69.861
# p(y=1 | [-2.03579191  4.08560307]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.3557574   2.81159358]) = 20.798
# p(y=1 | [-1.3557574   2.81159358]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.54187683  4.44185709]) = 43.825
# p(y=1 | [-0.54187683  4.44185709]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-11.08247771  -5.12837699]) = 0.000
# p(y=1 | [-11.08247771  -5.12837699]) = 21.944
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.85092948  5.66700555]) = 34.503
# p(y=1 | [-1.85092948  5.66700555]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.96113072  3.64518861]) = 56.209
# p(y=1 | [-1.96113072  3.64518861]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0.15097501 3.10076295]) = 6.825
# p(y=1 | [0.15097501 3.10076295]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.21390906  4.91317334]) = 59.294
# p(y=1 | [-2.21390906  4.91317334]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.36264076  -4.31520346]) = 0.000
# p(y=1 | [-10.36264076  -4.31520346]) = 69.091
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.79120866 -1.99680935]) = 0.000
# p(y=1 | [-8.79120866 -1.99680935]) = 5.792
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.79537265  2.67654187]) = 17.000
# p(y=1 | [-1.79537265  2.67654187]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.76907514 -4.5375795 ]) = 0.000
# p(y=1 | [-9.76907514 -4.5375795 ]) = 65.700
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.37148174  5.90459805]) = 24.331
# p(y=1 | [-1.37148174  5.90459805]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.43462678  -3.86608852]) = 0.000
# p(y=1 | [-10.43462678  -3.86608852]) = 71.083
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.25214931  4.32047636]) = 30.618
# p(y=1 | [-0.25214931  4.32047636]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.13070865  5.0143769 ]) = 57.910
# p(y=1 | [-1.13070865  5.0143769 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.92814969  5.34969319]) = 22.255
# p(y=1 | [-2.92814969  5.34969319]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-11.25459086  -5.17789214]) = 0.000
# p(y=1 | [-11.25459086  -5.17789214]) = 16.913
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.47498939  -3.58569403]) = 0.000
# p(y=1 | [-10.47498939  -3.58569403]) = 65.294
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.94872525  -3.32519699]) = 0.000
# p(y=1 | [-10.94872525  -3.32519699]) = 40.646
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.82490276  5.42630654]) = 33.640
# p(y=1 | [-0.82490276  5.42630654]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.47439814 -3.32314564]) = 0.000
# p(y=1 | [-9.47439814 -3.32314564]) = 57.187
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.03679539 -4.15124743]) = 0.000
# p(y=1 | [-8.03679539 -4.15124743]) = 12.380
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.91791528  4.3376365 ]) = 76.391
# p(y=1 | [-1.91791528  4.3376365 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-3.51094497  4.6163657 ]) = 13.835
# p(y=1 | [-3.51094497  4.6163657 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.20397465  4.34341883]) = 67.866
# p(y=1 | [-2.20397465  4.34341883]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.66170707  4.50962171]) = 79.091
# p(y=1 | [-1.66170707  4.50962171]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.93157544  4.44936892]) = 76.210
# p(y=1 | [-1.93157544  4.44936892]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.83510021  -4.99771617]) = 0.000
# p(y=1 | [-10.83510021  -4.99771617]) = 32.175
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.51900016  3.03792422]) = 30.289
# p(y=1 | [-1.51900016  3.03792422]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.85806023  4.32588287]) = 77.447
# p(y=1 | [-1.85806023  4.32588287]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.41830933 -3.19301122]) = 0.000
# p(y=1 | [-8.41830933 -3.19301122]) = 18.025
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.0024817   4.34487385]) = 64.947
# p(y=1 | [-1.0024817   4.34487385]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.42115998  -4.09934015]) = 0.000
# p(y=1 | [-10.42115998  -4.09934015]) = 71.145
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.08514036  4.51745136]) = 71.691
# p(y=1 | [-2.08514036  4.51745136]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.771378    3.21993817]) = 20.591
# p(y=1 | [-2.771378    3.21993817]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.58812928  3.27372202]) = 41.202
# p(y=1 | [-1.58812928  3.27372202]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.13769414  4.60893723]) = 25.561
# p(y=1 | [-0.13769414  4.60893723]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.24592817  4.73765356]) = 69.639
# p(y=1 | [-1.24592817  4.73765356]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.49968849 -5.37417665]) = 0.000
# p(y=1 | [-9.49968849 -5.37417665]) = 26.108
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.18256405  -4.33816776]) = 0.000
# p(y=1 | [-10.18256405  -4.33816776]) = 72.214
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.08120776  -3.76393747]) = 0.000
# p(y=1 | [-10.08120776  -3.76393747]) = 77.257
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.24466675  2.31083202]) = 7.783
# p(y=1 | [-1.24466675  2.31083202]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.94487689 -3.92208279]) = 0.000
# p(y=1 | [-8.94487689 -3.92208279]) = 47.117
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.27407996  -4.80970715]) = 0.000
# p(y=1 | [-11.27407996  -4.80970715]) = 24.147
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.51293905 -3.55396639]) = 0.000
# p(y=1 | [-8.51293905 -3.55396639]) = 25.630
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.42102192 -4.31417137]) = 0.000
# p(y=1 | [-9.42102192 -4.31417137]) = 64.062
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.43244361  4.10623956]) = 55.738
# p(y=1 | [-2.43244361  4.10623956]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.95966995  3.32857707]) = 18.599
# p(y=1 | [-2.95966995  3.32857707]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.87878325  4.45098036]) = 77.263
# p(y=1 | [-1.87878325  4.45098036]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.13468285  -4.67088028]) = 0.000
# p(y=1 | [-10.13468285  -4.67088028]) = 60.779
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.15732355  3.38218946]) = 40.760
# p(y=1 | [-2.15732355  3.38218946]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.49858422  4.51283959]) = 54.985
# p(y=1 | [-2.49858422  4.51283959]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.69698399 -3.64876562]) = 0.000
# p(y=1 | [-8.69698399 -3.64876562]) = 33.942
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.8371921   2.89603349]) = 24.286
# p(y=1 | [-1.8371921   2.89603349]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.28411255 -4.18198088]) = 0.000
# p(y=1 | [-8.28411255 -4.18198088]) = 19.088
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.81827495  -3.11242088]) = 0.000
# p(y=1 | [-10.81827495  -3.11242088]) = 38.979
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.51716313  -4.34669455]) = 0.000
# p(y=1 | [-10.51716313  -4.34669455]) = 63.642
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.49559492  3.50678745]) = 52.033
# p(y=1 | [-1.49559492  3.50678745]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.94338508 -4.33318429]) = 0.000
# p(y=1 | [-8.94338508 -4.33318429]) = 43.926
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.80336831 -4.02280729]) = 0.000
# p(y=1 | [-8.80336831 -4.02280729]) = 40.407
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-5.31600001  3.16348093]) = 0.046
# p(y=1 | [-5.31600001  3.16348093]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.24184651  4.43678788]) = 73.511
# p(y=1 | [-1.24184651  4.43678788]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-11.45876838  -2.47856995]) = 0.000
# p(y=1 | [-11.45876838  -2.47856995]) = 8.965
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.14705003 -6.21333229]) = 0.000
# p(y=1 | [-8.14705003 -6.21333229]) = 1.219
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.2973171  -4.06015486]) = 0.000
# p(y=1 | [-9.2973171  -4.06015486]) = 62.984
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.92991021 -4.05255924]) = 0.000
# p(y=1 | [-9.92991021 -4.05255924]) = 78.806
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.01860193  -3.3611508 ]) = 0.000
# p(y=1 | [-11.01860193  -3.3611508 ]) = 38.785
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.70046592  5.06905752]) = 41.083
# p(y=1 | [-0.70046592  5.06905752]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.83679887  2.48440264]) = 8.736
# p(y=1 | [-0.83679887  2.48440264]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-3.81582001  5.42831003]) = 4.511
# p(y=1 | [-3.81582001  5.42831003]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.21357681 -3.11307699]) = 0.000
# p(y=1 | [-9.21357681 -3.11307699]) = 41.645
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.82241652 -4.74403038]) = 0.000
# p(y=1 | [-9.82241652 -4.74403038]) = 57.622
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.59328589 -5.50048862]) = 0.000
# p(y=1 | [-9.59328589 -5.50048862]) = 22.529
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.70523192 -2.48813962]) = 0.000
# p(y=1 | [-9.70523192 -2.48813962]) = 25.824
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0.13899203 4.83769662]) = 15.162
# p(y=1 | [0.13899203 4.83769662]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-11.40717158  -3.70026576]) = 0.000
# p(y=1 | [-11.40717158  -3.70026576]) = 28.013
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.60431587  5.92279033]) = 24.502
# p(y=1 | [-1.60431587  5.92279033]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.42768283  4.61958453]) = 57.235
# p(y=1 | [-2.42768283  4.61958453]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.53118292  6.16690505]) = 16.185
# p(y=1 | [-1.53118292  6.16690505]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.7080111  3.9318801]) = 40.394
# p(y=1 | [-2.7080111  3.9318801]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.62621149  6.16706219]) = 16.275
# p(y=1 | [-1.62621149  6.16706219]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-12.23031278  -4.38910146]) = 0.000
# p(y=1 | [-12.23031278  -4.38910146]) = 5.977
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-3.8586179   5.33664687]) = 4.506
# p(y=1 | [-3.8586179   5.33664687]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.35402429  -3.35841465]) = 0.000
# p(y=1 | [-10.35402429  -3.35841465]) = 61.551
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.83738835  3.42197534]) = 23.890
# p(y=1 | [-2.83738835  3.42197534]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.88068819  -4.85956356]) = 0.000
# p(y=1 | [-10.88068819  -4.85956356]) = 35.359
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.67539769  -4.45382996]) = 0.000
# p(y=1 | [-11.67539769  -4.45382996]) = 17.003
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.67170175  -3.08307372]) = 0.000
# p(y=1 | [-11.67170175  -3.08307372]) = 13.139
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.29464733  3.51211923]) = 42.772
# p(y=1 | [-2.29464733  3.51211923]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-11.03166654  -3.53494197]) = 0.000
# p(y=1 | [-11.03166654  -3.53494197]) = 41.838
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.51651347 -4.14718782]) = 0.000
# p(y=1 | [-9.51651347 -4.14718782]) = 70.261
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.4743129   -3.39855793]) = 0.000
# p(y=1 | [-10.4743129   -3.39855793]) = 59.826
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.29089421  4.51112219]) = 74.470
# p(y=1 | [-1.29089421  4.51112219]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.73364203 -4.55825316]) = 0.000
# p(y=1 | [-9.73364203 -4.55825316]) = 64.406
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.05602769 -4.55892189]) = 0.000
# p(y=1 | [-9.05602769 -4.55892189]) = 43.832
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.35135577  5.52197924]) = 40.369
# p(y=1 | [-1.35135577  5.52197924]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.13812586  5.27773815]) = 17.710
# p(y=1 | [-0.13812586  5.27773815]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-12.51314681  -3.67298665]) = 0.000
# p(y=1 | [-12.51314681  -3.67298665]) = 3.235
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.68191928  3.00601989]) = 29.137
# p(y=1 | [-1.68191928  3.00601989]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.20794396  5.5106642 ]) = 38.856
# p(y=1 | [-1.20794396  5.5106642 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.69605169 -4.01074424]) = 0.000
# p(y=1 | [-8.69605169 -4.01074424]) = 35.552
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.78198959  4.12156941]) = 75.558
# p(y=1 | [-1.78198959  4.12156941]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.92206212 -2.20937032]) = 0.000
# p(y=1 | [-9.92206212 -2.20937032]) = 17.040
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.48258124  4.83503965]) = 51.021
# p(y=1 | [-2.48258124  4.83503965]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.87385474 -3.05063687]) = 0.000
# p(y=1 | [-9.87385474 -3.05063687]) = 52.070
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-3.3132298   3.37604389]) = 11.615
# p(y=1 | [-3.3132298   3.37604389]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.29537517  2.46000846]) = 10.794
# p(y=1 | [-1.29537517  2.46000846]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.80297698 -5.39952052]) = 0.000
# p(y=1 | [-9.80297698 -5.39952052]) = 27.715
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0.02145446 3.75965002]) = 16.438
# p(y=1 | [0.02145446 3.75965002]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.54213761 -4.32384301]) = 0.000
# p(y=1 | [-9.54213761 -4.32384301]) = 67.681
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.97884076  4.21782353]) = 73.816
# p(y=1 | [-1.97884076  4.21782353]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.34969358  4.09605508]) = 72.627
# p(y=1 | [-1.34969358  4.09605508]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.49827421  5.47645541]) = 23.256
# p(y=1 | [-0.49827421  5.47645541]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.53671567  -3.09218663]) = 0.000
# p(y=1 | [-10.53671567  -3.09218663]) = 46.505
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.2559005   3.69561463]) = 50.951
# p(y=1 | [-2.2559005   3.69561463]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.18647629  5.71182469]) = 28.700
# p(y=1 | [-2.18647629  5.71182469]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.49209003  4.71870278]) = 39.477
# p(y=1 | [-0.49209003  4.71870278]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.86695129 -2.90945934]) = 0.000
# p(y=1 | [-9.86695129 -2.90945934]) = 45.300
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.78053398  -5.7567024 ]) = 0.000
# p(y=1 | [-10.78053398  -5.7567024 ]) = 11.470
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.25201991  4.53559145]) = 30.467
# p(y=1 | [-0.25201991  4.53559145]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.78103537 -3.87826757]) = 0.000
# p(y=1 | [-9.78103537 -3.87826757]) = 77.515
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.78638329  -4.96480383]) = 0.000
# p(y=1 | [-10.78638329  -4.96480383]) = 34.630
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.28808184  -3.09510122]) = 0.000
# p(y=1 | [-10.28808184  -3.09510122]) = 51.873
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-3.22529806  5.42031234]) = 13.608
# p(y=1 | [-3.22529806  5.42031234]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.19017264  5.03590098]) = 55.940
# p(y=1 | [-2.19017264  5.03590098]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.10788301  5.09917878]) = 55.855
# p(y=1 | [-2.10788301  5.09917878]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.52924732 -2.53437418]) = 0.000
# p(y=1 | [-8.52924732 -2.53437418]) = 10.293
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.35558758  6.34362145]) = 9.054
# p(y=1 | [-2.35558758  6.34362145]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.4925541   4.84081294]) = 71.442
# p(y=1 | [-1.4925541   4.84081294]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.19994135 -4.29267029]) = 0.000
# p(y=1 | [-9.19994135 -4.29267029]) = 55.898
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.32695339 -3.81893902]) = 0.000
# p(y=1 | [-8.32695339 -3.81893902]) = 20.769
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0.48035853 3.15337062]) = 3.872
# p(y=1 | [0.48035853 3.15337062]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.36437673  4.73424122]) = 33.712
# p(y=1 | [-0.36437673  4.73424122]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0.17649986 4.80844123]) = 14.364
# p(y=1 | [0.17649986 4.80844123]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.62263889 -2.22176401]) = 0.000
# p(y=1 | [-9.62263889 -2.22176401]) = 16.412
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.42951326  -3.86293565]) = 0.000
# p(y=1 | [-10.42951326  -3.86293565]) = 71.224
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.72421627  3.21614169]) = 25.463
# p(y=1 | [-0.72421627  3.21614169]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.33644737 -0.87626949]) = 0.000
# p(y=1 | [-9.33644737 -0.87626949]) = 0.555
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.03864762  3.60030505]) = 16.086
# p(y=1 | [-0.03864762  3.60030505]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-3.79687209  2.2515737 ]) = 0.745
# p(y=1 | [-3.79687209  2.2515737 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.41215458  -3.89958958]) = 0.000
# p(y=1 | [-10.41215458  -3.89958958]) = 71.977
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-3.68576632  4.40754464]) = 10.095
# p(y=1 | [-3.68576632  4.40754464]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-3.52009064  3.11421325]) = 5.921
# p(y=1 | [-3.52009064  3.11421325]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0.57645541 3.5485952 ]) = 4.830
# p(y=1 | [0.57645541 3.5485952 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.45084388  4.08326825]) = 37.513
# p(y=1 | [-0.45084388  4.08326825]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0.48442601 3.91509886]) = 7.577
# p(y=1 | [0.48442601 3.91509886]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0.10068932 4.34583738]) = 17.791
# p(y=1 | [0.10068932 4.34583738]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.88831122 -4.04781385]) = 0.000
# p(y=1 | [-8.88831122 -4.04781385]) = 44.301
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.78027037  4.40939816]) = 78.777
# p(y=1 | [-1.78027037  4.40939816]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.85458078  2.43224211]) = 10.585
# p(y=1 | [-1.85458078  2.43224211]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.66391229 -3.69858794]) = 0.000
# p(y=1 | [-8.66391229 -3.69858794]) = 33.019
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0.47719855 4.7654132 ]) = 8.147
# p(y=1 | [0.47719855 4.7654132 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.57600342 -4.05571337]) = 0.000
# p(y=1 | [-8.57600342 -4.05571337]) = 30.278
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.27452812  4.70187321]) = 30.297
# p(y=1 | [-0.27452812  4.70187321]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.94867749 -4.53986849]) = 0.000
# p(y=1 | [-8.94867749 -4.53986849]) = 40.022
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.6749304   2.81942105]) = 13.842
# p(y=1 | [-0.6749304   2.81942105]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.30016565  -2.74291711]) = 0.000
# p(y=1 | [-10.30016565  -2.74291711]) = 35.793
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.67953878  4.95641464]) = 39.989
# p(y=1 | [-2.67953878  4.95641464]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.98895164 -5.44615808]) = 0.000
# p(y=1 | [-9.98895164 -5.44615808]) = 26.258
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.03120178  -2.88926156]) = 0.000
# p(y=1 | [-10.03120178  -2.88926156]) = 44.517
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.06770409  -3.61672206]) = 0.000
# p(y=1 | [-11.06770409  -3.61672206]) = 41.569
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.97681149 -2.37922299]) = 0.000
# p(y=1 | [-9.97681149 -2.37922299]) = 22.651
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.17618727 -3.62026524]) = 0.000
# p(y=1 | [-8.17618727 -3.62026524]) = 15.351
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.07103551  -4.66858042]) = 0.000
# p(y=1 | [-10.07103551  -4.66858042]) = 61.368
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.27399021  2.65909274]) = 13.680
# p(y=1 | [-2.27399021  2.65909274]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.46531037  4.66022261]) = 75.805
# p(y=1 | [-1.46531037  4.66022261]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-3.54061241  4.49943191]) = 13.332
# p(y=1 | [-3.54061241  4.49943191]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.61342271 -4.37167247]) = 0.000
# p(y=1 | [-9.61342271 -4.37167247]) = 68.304
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.42706535  5.08904128]) = 61.270
# p(y=1 | [-1.42706535  5.08904128]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.9994495   4.71614697]) = 71.061
# p(y=1 | [-1.9994495   4.71614697]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.68639851 -2.94551364]) = 0.000
# p(y=1 | [-8.68639851 -2.94551364]) = 20.993
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.94122801 -4.56785796]) = 0.000
# p(y=1 | [-8.94122801 -4.56785796]) = 39.068
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.89599686  5.13430337]) = 58.722
# p(y=1 | [-1.89599686  5.13430337]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.26653346 -4.31855748]) = 0.000
# p(y=1 | [-9.26653346 -4.31855748]) = 58.144
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.95881222 -3.15140021]) = 0.000
# p(y=1 | [-9.95881222 -3.15140021]) = 57.061
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.78699014  4.49780181]) = 41.401
# p(y=1 | [-2.78699014  4.49780181]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.10431518 -2.84459722]) = 0.000
# p(y=1 | [-8.10431518 -2.84459722]) = 7.664
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.41932621  -4.78928157]) = 0.000
# p(y=1 | [-11.41932621  -4.78928157]) = 20.208
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.16516689  -4.83864049]) = 0.000
# p(y=1 | [-10.16516689  -4.83864049]) = 52.915
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.88927913  -3.60336828]) = 0.000
# p(y=1 | [-10.88927913  -3.60336828]) = 49.311
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.6387393   5.37159553]) = 49.374
# p(y=1 | [-1.6387393   5.37159553]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.50665485  3.3691772 ]) = 45.468
# p(y=1 | [-1.50665485  3.3691772 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.56636868  -5.83810685]) = 0.000
# p(y=1 | [-10.56636868  -5.83810685]) = 11.436
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.85849736  4.70844991]) = 74.150
# p(y=1 | [-1.85849736  4.70844991]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.31580691  4.68605183]) = 61.016
# p(y=1 | [-2.31580691  4.68605183]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.21509301 -4.52873344]) = 0.000
# p(y=1 | [-9.21509301 -4.52873344]) = 50.836
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.56381343 -2.3409384 ]) = 0.000
# p(y=1 | [-9.56381343 -2.3409384 ]) = 19.618
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.94752806 -5.43420521]) = 0.000
# p(y=1 | [-9.94752806 -5.43420521]) = 26.720
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0.35508897 4.99337461]) = 9.348
# p(y=1 | [0.35508897 4.99337461]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.76718343 -3.48860266]) = 0.000
# p(y=1 | [-8.76718343 -3.48860266]) = 34.716
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.00141708  -4.31597959]) = 0.000
# p(y=1 | [-11.00141708  -4.31597959]) = 44.360
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.54621165  4.0817476 ]) = 75.039
# p(y=1 | [-1.54621165  4.0817476 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.13825505  -3.36416673]) = 0.000
# p(y=1 | [-10.13825505  -3.36416673]) = 65.418
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.06528836  4.62234954]) = 65.970
# p(y=1 | [-1.06528836  4.62234954]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.75286381  4.6309406 ]) = 42.089
# p(y=1 | [-2.75286381  4.6309406 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.89188968  4.40445108]) = 77.098
# p(y=1 | [-1.89188968  4.40445108]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.20130545  3.57195768]) = 47.693
# p(y=1 | [-2.20130545  3.57195768]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.8476628  -3.9390449]) = 0.000
# p(y=1 | [-10.8476628  -3.9390449]) = 54.506
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.49402804 -1.72591777]) = 0.000
# p(y=1 | [-9.49402804 -1.72591777]) = 5.810
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.3575488  -2.00524355]) = 0.000
# p(y=1 | [-9.3575488  -2.00524355]) = 9.699
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.81979802  5.12876999]) = 59.936
# p(y=1 | [-1.81979802  5.12876999]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.50830131 -4.45686605]) = 0.000
# p(y=1 | [-9.50830131 -4.45686605]) = 62.976
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.19145918  7.25427199]) = 1.134
# p(y=1 | [-1.19145918  7.25427199]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0.33213722 4.37135161]) = 11.656
# p(y=1 | [0.33213722 4.37135161]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-11.69269118  -3.41391904]) = 0.000
# p(y=1 | [-11.69269118  -3.41391904]) = 16.060
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.81671255  -1.81071144]) = 0.000
# p(y=1 | [-11.81671255  -1.81071144]) = 1.486
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.13357716  -3.55268139]) = 0.000
# p(y=1 | [-11.13357716  -3.55268139]) = 37.735
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.86354209  5.51023789]) = 31.653
# p(y=1 | [-0.86354209  5.51023789]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.52185342  4.00542075]) = 49.932
# p(y=1 | [-2.52185342  4.00542075]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.99500507  6.13388961]) = 16.230
# p(y=1 | [-1.99500507  6.13388961]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.45190761 -2.74048119]) = 0.000
# p(y=1 | [-9.45190761 -2.74048119]) = 32.893
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.3502421   7.32379863]) = 0.979
# p(y=1 | [-1.3502421   7.32379863]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.39787041  3.02602797]) = 29.145
# p(y=1 | [-1.39787041  3.02602797]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.17714043  4.61792484]) = 67.438
# p(y=1 | [-2.17714043  4.61792484]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.54496647 -4.55805872]) = 0.000
# p(y=1 | [-9.54496647 -4.55805872]) = 60.549
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.10925362  -1.66701175]) = 0.000
# p(y=1 | [-10.10925362  -1.66701175]) = 5.640
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-12.32169205  -4.8985182 ]) = 0.000
# p(y=1 | [-12.32169205  -4.8985182 ]) = 3.434
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.41287844  -2.46970935]) = 0.000
# p(y=1 | [-10.41287844  -2.46970935]) = 23.692
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.67098182  4.16366345]) = 48.544
# p(y=1 | [-0.67098182  4.16366345]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.89709116 -3.17720914]) = 0.000
# p(y=1 | [-9.89709116 -3.17720914]) = 58.085
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.10481569  -2.84421074]) = 0.000
# p(y=1 | [-10.10481569  -2.84421074]) = 42.089
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.44227728  5.38690287]) = 35.407
# p(y=1 | [-2.44227728  5.38690287]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.70936066  4.95117135]) = 44.552
# p(y=1 | [-0.70936066  4.95117135]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.94798052  4.0771299 ]) = 71.819
# p(y=1 | [-1.94798052  4.0771299 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.37080406 -3.87914831]) = 0.000
# p(y=1 | [-9.37080406 -3.87914831]) = 66.059
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-7.99415331 -2.39679665]) = 0.000
# p(y=1 | [-7.99415331 -2.39679665]) = 3.415
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.23336677  -2.58630909]) = 0.000
# p(y=1 | [-10.23336677  -2.58630909]) = 29.776
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.18659543  -3.41561742]) = 0.000
# p(y=1 | [-10.18659543  -3.41561742]) = 66.772
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.54645233  -5.21231248]) = 0.000
# p(y=1 | [-10.54645233  -5.21231248]) = 30.815
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.86646149  -3.01686433]) = 0.000
# p(y=1 | [-10.86646149  -3.01686433]) = 34.341
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.41080763  4.16508002]) = 36.617
# p(y=1 | [-0.41080763  4.16508002]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.50522084  -4.04255079]) = 0.000
# p(y=1 | [-10.50522084  -4.04255079]) = 68.767
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.11361659 -3.81237339]) = 0.000
# p(y=1 | [-9.11361659 -3.81237339]) = 54.516
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.22387543  -2.6898482 ]) = 0.000
# p(y=1 | [-10.22387543  -2.6898482 ]) = 34.232
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.83131334 -4.20557276]) = 0.000
# p(y=1 | [-9.83131334 -4.20557276]) = 76.111
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.96253512  -4.54332633]) = 0.000
# p(y=1 | [-10.96253512  -4.54332633]) = 41.431
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.26076274  -4.64473405]) = 0.000
# p(y=1 | [-10.26076274  -4.64473405]) = 60.212
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.73050135  -4.82964579]) = 0.000
# p(y=1 | [-10.73050135  -4.82964579]) = 41.030
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.74630105  5.34900301]) = 34.024
# p(y=1 | [-0.74630105  5.34900301]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.87952088 -3.73028056]) = 0.000
# p(y=1 | [-8.87952088 -3.73028056]) = 42.897
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.6154953   -3.26964375]) = 0.000
# p(y=1 | [-11.6154953   -3.26964375]) = 16.676
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.11963271 -4.27823272]) = 0.000
# p(y=1 | [-8.11963271 -4.27823272]) = 13.980
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.38567842 -4.63901575]) = 0.000
# p(y=1 | [-9.38567842 -4.63901575]) = 53.112
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.7344958  -4.50839662]) = 0.000
# p(y=1 | [-9.7344958  -4.50839662]) = 66.286
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.56487761  3.86832742]) = 68.399
# p(y=1 | [-1.56487761  3.86832742]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.99844544  2.80927562]) = 17.597
# p(y=1 | [-0.99844544  2.80927562]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-3.22884312  4.10670175]) = 21.875
# p(y=1 | [-3.22884312  4.10670175]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.45765368  5.44946328]) = 44.832
# p(y=1 | [-1.45765368  5.44946328]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-4.19525896  4.85590936]) = 2.864
# p(y=1 | [-4.19525896  4.85590936]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.81074573  5.41818581]) = 46.431
# p(y=1 | [-1.81074573  5.41818581]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.52048771 -5.69102197]) = 0.000
# p(y=1 | [-8.52048771 -5.69102197]) = 6.292
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.10549155  -3.958229  ]) = 0.000
# p(y=1 | [-10.10549155  -3.958229  ]) = 78.548
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.41047095  3.00661062]) = 13.836
# p(y=1 | [-0.41047095  3.00661062]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.97103988 -5.49982818]) = 0.000
# p(y=1 | [-9.97103988 -5.49982818]) = 24.212
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.85352751 -4.70591088]) = 0.000
# p(y=1 | [-9.85352751 -4.70591088]) = 59.574
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.87018444 -3.28081585]) = 0.000
# p(y=1 | [-8.87018444 -3.28081585]) = 34.602
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.41299599  -3.03938342]) = 0.000
# p(y=1 | [-11.41299599  -3.03938342]) = 18.794
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.80025966  3.47321434]) = 50.306
# p(y=1 | [-1.80025966  3.47321434]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.76558878  5.1076228 ]) = 61.365
# p(y=1 | [-1.76558878  5.1076228 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-11.33704025  -2.43338615]) = 0.000
# p(y=1 | [-11.33704025  -2.43338615]) = 9.925
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.87540828 -2.78214507]) = 0.000
# p(y=1 | [-8.87540828 -2.78214507]) = 21.882
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.82780731  3.09782817]) = 32.550
# p(y=1 | [-1.82780731  3.09782817]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.95305599 -4.42792758]) = 0.000
# p(y=1 | [-9.95305599 -4.42792758]) = 71.005
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.3311913  -4.70972707]) = 0.000
# p(y=1 | [-8.3311913  -4.70972707]) = 15.954
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [0.25250884 4.27614794]) = 13.459
# p(y=1 | [0.25250884 4.27614794]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.25091964  3.19477098]) = 31.225
# p(y=1 | [-2.25091964  3.19477098]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.22106996 -3.04360716]) = 0.000
# p(y=1 | [-9.22106996 -3.04360716]) = 39.385
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.26210266 -4.15915622]) = 0.000
# p(y=1 | [-9.26210266 -4.15915622]) = 60.594
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.50540716 -3.22303186]) = 0.000
# p(y=1 | [-9.50540716 -3.22303186]) = 54.169
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.72042057  3.65838399]) = 59.553
# p(y=1 | [-1.72042057  3.65838399]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.57941157 -4.40090872]) = 0.000
# p(y=1 | [-9.57941157 -4.40090872]) = 66.615
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.52731213  3.84325326]) = 67.204
# p(y=1 | [-1.52731213  3.84325326]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-7.34166642 -2.44280384]) = 0.000
# p(y=1 | [-7.34166642 -2.44280384]) = 0.840
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.01970965  -4.29076893]) = 0.000
# p(y=1 | [-11.01970965  -4.29076893]) = 43.922
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.77284336 -3.83090432]) = 0.000
# p(y=1 | [-9.77284336 -3.83090432]) = 77.004
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-7.51516657 -5.24630745]) = 0.000
# p(y=1 | [-7.51516657 -5.24630745]) = 1.794
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.73314607  -4.83618528]) = 0.000
# p(y=1 | [-10.73314607  -4.83618528]) = 40.717
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.8004714  -3.90570854]) = 0.000
# p(y=1 | [-9.8004714  -3.90570854]) = 77.933
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.0725768  -2.34335949]) = 0.000
# p(y=1 | [-9.0725768  -2.34335949]) = 14.365
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.11600546  5.40711093]) = 42.610
# p(y=1 | [-2.11600546  5.40711093]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# ...
#
# Right
#
# p(y=0 | [-8.79954157 -6.38798027]) = 0.000
# p(y=1 | [-8.79954157 -6.38798027]) = 2.114
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.94857471 -4.06967532]) = 0.000
# p(y=1 | [-8.94857471 -4.06967532]) = 47.048
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.91758836  3.62347988]) = 25.992
# p(y=1 | [-2.91758836  3.62347988]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.1164947   5.78827677]) = 9.517
# p(y=1 | [-0.1164947   5.78827677]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.32233897  5.4145553 ]) = 44.976
# p(y=1 | [-1.32233897  5.4145553 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.64401275 -2.45220006]) = 0.000
# p(y=1 | [-9.64401275 -2.45220006]) = 24.040
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.96311929  -3.61959082]) = 0.000
# p(y=1 | [-10.96311929  -3.61959082]) = 46.293
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.08282806  -4.46037168]) = 0.000
# p(y=1 | [-11.08282806  -4.46037168]) = 38.300
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.42801201  3.49952613]) = 51.073
# p(y=1 | [-1.42801201  3.49952613]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.95207008  -3.56161388]) = 0.000
# p(y=1 | [-10.95207008  -3.56161388]) = 45.793
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.71344741  5.33290209]) = 33.547
# p(y=1 | [-0.71344741  5.33290209]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.05658089  3.05731466]) = 26.492
# p(y=1 | [-1.05658089  3.05731466]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.98637559 -1.15452914]) = 0.000
# p(y=1 | [-8.98637559 -1.15452914]) = 0.954
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.8863201   2.84198202]) = 22.068
# p(y=1 | [-1.8863201   2.84198202]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-11.41806142  -3.87799123]) = 0.000
# p(y=1 | [-11.41806142  -3.87799123]) = 28.442
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.53674404 -3.30210379]) = 0.000
# p(y=1 | [-9.53674404 -3.30210379]) = 58.049
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.04378345  -4.93316328]) = 0.000
# p(y=1 | [-10.04378345  -4.93316328]) = 49.237
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.19626532  3.7731152 ]) = 55.626
# p(y=1 | [-2.19626532  3.7731152 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.27265971  6.03190085]) = 19.244
# p(y=1 | [-1.27265971  6.03190085]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.67449883 -1.69102962]) = 0.000
# p(y=1 | [-9.67449883 -1.69102962]) = 5.753
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-3.40896533  5.73241255]) = 6.910
# p(y=1 | [-3.40896533  5.73241255]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.58539447  4.25315064]) = 78.476
# p(y=1 | [-1.58539447  4.25315064]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.81741464  4.39272966]) = 56.940
# p(y=1 | [-0.81741464  4.39272966]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.65468337 -4.1513648 ]) = 0.000
# p(y=1 | [-9.65468337 -4.1513648 ]) = 73.996
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.97157787  -5.81995137]) = 0.000
# p(y=1 | [-10.97157787  -5.81995137]) = 8.631
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.34140571  4.38725823]) = 76.096
# p(y=1 | [-1.34140571  4.38725823]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.66443538  -2.96128389]) = 0.000
# p(y=1 | [-10.66443538  -2.96128389]) = 38.047
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.25087096 -3.50402342]) = 0.000
# p(y=1 | [-9.25087096 -3.50402342]) = 55.232
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.4043049  -2.98608469]) = 0.000
# p(y=1 | [-9.4043049  -2.98608469]) = 41.998
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.12417826  -3.73897573]) = 0.000
# p(y=1 | [-11.12417826  -3.73897573]) = 40.445
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.03071467  -3.36220897]) = 0.000
# p(y=1 | [-10.03071467  -3.36220897]) = 66.104
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.11140201  3.29120626]) = 36.667
# p(y=1 | [-1.11140201  3.29120626]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.21014758  5.86629221]) = 24.388
# p(y=1 | [-1.21014758  5.86629221]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.28124983  -6.04276386]) = 0.000
# p(y=1 | [-10.28124983  -6.04276386]) = 8.644
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.81450393  2.4073467 ]) = 5.213
# p(y=1 | [-2.81450393  2.4073467 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.2422433  3.1213141]) = 31.597
# p(y=1 | [-1.2422433  3.1213141]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.08241687  4.49295428]) = 71.954
# p(y=1 | [-2.08241687  4.49295428]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.20057665  3.73187923]) = 53.983
# p(y=1 | [-2.20057665  3.73187923]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.74009191  3.87947623]) = 37.998
# p(y=1 | [-2.74009191  3.87947623]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.22799451  4.65146563]) = 65.050
# p(y=1 | [-2.22799451  4.65146563]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.20662484  -3.62332387]) = 0.000
# p(y=1 | [-10.20662484  -3.62332387]) = 72.870
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.4312221   -3.82608002]) = 0.000
# p(y=1 | [-11.4312221   -3.82608002]) = 27.758
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.79253387  5.05745338]) = 33.258
# p(y=1 | [-2.79253387  5.05745338]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.45266337  4.3889396 ]) = 57.430
# p(y=1 | [-2.45266337  4.3889396 ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.45295734  -3.24852405]) = 0.000
# p(y=1 | [-10.45295734  -3.24852405]) = 54.925
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.88305139 -4.57941901]) = 0.000
# p(y=1 | [-9.88305139 -4.57941901]) = 65.144
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.00803105  4.94419496]) = 64.169
# p(y=1 | [-2.00803105  4.94419496]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.39954769 -3.37915703]) = 0.000
# p(y=1 | [-9.39954769 -3.37915703]) = 56.890
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-4.95441831  4.49732965]) = 0.351
# p(y=1 | [-4.95441831  4.49732965]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.01339558 -4.36133831]) = 0.000
# p(y=1 | [-9.01339558 -4.36133831]) = 46.520
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.14548618  -4.64054647]) = 0.000
# p(y=1 | [-10.14548618  -4.64054647]) = 61.966
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-3.46420679  4.429091  ]) = 15.406
# p(y=1 | [-3.46420679  4.429091  ]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.8829401  -4.07913602]) = 0.000
# p(y=1 | [-8.8829401  -4.07913602]) = 43.907
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.12928534 -3.97950154]) = 0.000
# p(y=1 | [-8.12928534 -3.97950154]) = 14.960
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.54666875  3.51554333]) = 52.768
# p(y=1 | [-1.54666875  3.51554333]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.72743648  4.32981051]) = 44.266
# p(y=1 | [-2.72743648  4.32981051]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-7.80336984 -4.56229299]) = 0.000
# p(y=1 | [-7.80336984 -4.56229299]) = 6.578
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-4.17448453  5.22111488]) = 2.382
# p(y=1 | [-4.17448453  5.22111488]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.34893609  4.28104267]) = 75.667
# p(y=1 | [-1.34893609  4.28104267]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.81726357 -2.1711471 ]) = 0.000
# p(y=1 | [-9.81726357 -2.1711471 ]) = 15.754
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.22456158  5.31691347]) = 47.780
# p(y=1 | [-1.22456158  5.31691347]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0.3950642  4.45989941]) = 10.283
# p(y=1 | [0.3950642  4.45989941]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-12.28875078  -4.74983455]) = 0.000
# p(y=1 | [-12.28875078  -4.74983455]) = 4.210
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.94415026  -2.38622984]) = 0.000
# p(y=1 | [-10.94415026  -2.38622984]) = 14.449
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.4261539   3.24461877]) = 38.979
# p(y=1 | [-1.4261539   3.24461877]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [0.06094079 6.15820782]) = 3.965
# p(y=1 | [0.06094079 6.15820782]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.08909537  -3.89876469]) = 0.000
# p(y=1 | [-10.08909537  -3.89876469]) = 78.552
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.62779089 -3.45014212]) = 0.000
# p(y=1 | [-9.62779089 -3.45014212]) = 65.554
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.46927531  4.35501716]) = 56.595
# p(y=1 | [-2.46927531  4.35501716]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.76595408 -4.76691985]) = 0.000
# p(y=1 | [-8.76595408 -4.76691985]) = 27.999
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.10551412  -5.25842152]) = 0.000
# p(y=1 | [-10.10551412  -5.25842152]) = 33.821
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.69585921  2.84345283]) = 14.675
# p(y=1 | [-0.69585921  2.84345283]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.90349921  4.45847041]) = 76.764
# p(y=1 | [-1.90349921  4.45847041]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.69416363  4.75549383]) = 43.205
# p(y=1 | [-2.69416363  4.75549383]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.12253567  4.62362927]) = 69.228
# p(y=1 | [-2.12253567  4.62362927]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.67932897  4.92512909]) = 69.254
# p(y=1 | [-1.67932897  4.92512909]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.27002315  3.35031773]) = 36.967
# p(y=1 | [-2.27002315  3.35031773]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.52105117 -5.26975812]) = 0.000
# p(y=1 | [-8.52105117 -5.26975812]) = 11.951
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.55152909  4.43590749]) = 79.197
# p(y=1 | [-1.55152909  4.43590749]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [1.19486418 4.11235759]) = 1.441
# p(y=1 | [1.19486418 4.11235759]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.9336518   -4.31846067]) = 0.000
# p(y=1 | [-10.9336518   -4.31846067]) = 47.341
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-11.0020147   -2.09545536]) = 0.000
# p(y=1 | [-11.0020147   -2.09545536]) = 8.276
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.73610128 -5.17309355]) = 0.000
# p(y=1 | [-8.73610128 -5.17309355]) = 17.924
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.93287994  4.03452993]) = 57.891
# p(y=1 | [-0.93287994  4.03452993]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.77730687 -3.64858172]) = 0.000
# p(y=1 | [-9.77730687 -3.64858172]) = 74.023
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.58307771 -4.20275488]) = 0.000
# p(y=1 | [-8.58307771 -4.20275488]) = 29.824
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.51667467  -3.19812695]) = 0.000
# p(y=1 | [-10.51667467  -3.19812695]) = 51.260
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.15157557  4.08245754]) = 67.002
# p(y=1 | [-1.15157557  4.08245754]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-10.26077749  -3.90435528]) = 0.000
# p(y=1 | [-10.26077749  -3.90435528]) = 75.970
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.46063394 -2.25389943]) = 0.000
# p(y=1 | [-9.46063394 -2.25389943]) = 16.197
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.79415228  2.10495117]) = 3.716
# p(y=1 | [-0.79415228  2.10495117]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.14673997  3.63049535]) = 19.442
# p(y=1 | [-0.14673997  3.63049535]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-11.29258421  -3.19672904]) = 0.000
# p(y=1 | [-11.29258421  -3.19672904]) = 25.250
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.09814626  -4.10198969]) = 0.000
# p(y=1 | [-10.09814626  -4.10198969]) = 77.840
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.16100617  -4.3766343 ]) = 0.000
# p(y=1 | [-10.16100617  -4.3766343 ]) = 71.418
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.40280498  4.02518303]) = 71.816
# p(y=1 | [-1.40280498  4.02518303]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.66528347 -3.46679822]) = 0.000
# p(y=1 | [-9.66528347 -3.46679822]) = 66.905
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-1.37910281  4.01045228]) = 70.981
# p(y=1 | [-1.37910281  4.01045228]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.18379953  4.78043324]) = 66.806
# p(y=1 | [-1.18379953  4.78043324]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.95461357 -3.70385889]) = 0.000
# p(y=1 | [-9.95461357 -3.70385889]) = 76.624
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.36734228  3.66210269]) = 46.160
# p(y=1 | [-2.36734228  3.66210269]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.4543593   5.52615994]) = 41.158
# p(y=1 | [-1.4543593   5.52615994]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-2.14670215  4.47611841]) = 69.916
# p(y=1 | [-2.14670215  4.47611841]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-0.51542336  2.69188212]) = 9.466
# p(y=1 | [-0.51542336  2.69188212]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-9.77921004 -2.55823735]) = 0.000
# p(y=1 | [-9.77921004 -2.55823735]) = 29.049
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-9.82675388 -3.94841667]) = 0.000
# p(y=1 | [-9.82675388 -3.94841667]) = 78.369
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-0.26973395  4.41324015]) = 31.478
# p(y=1 | [-0.26973395  4.41324015]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.15754093  3.47885251]) = 45.653
# p(y=1 | [-1.15754093  3.47885251]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-8.85442845 -5.69322958]) = 0.000
# p(y=1 | [-8.85442845 -5.69322958]) = 9.547
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-10.05223518  -3.83894309]) = 0.000
# p(y=1 | [-10.05223518  -3.83894309]) = 78.393
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-8.32590235 -3.28406147]) = 0.000
# p(y=1 | [-8.32590235 -3.28406147]) = 16.653
# model predicted class 1 and the truth was 1
#
# Right
#
# p(y=0 | [-2.4684071   4.96392932]) = 48.369
# p(y=1 | [-2.4684071   4.96392932]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# p(y=0 | [-1.79844127  7.05862955]) = 2.147
# p(y=1 | [-1.79844127  7.05862955]) = 0.000
# model predicted class 0 and the truth was 0
#
# Right
#
# Total Correct Classifications are : 3000
# Total Wrong Classifications are : 0
